# %% [markdown]
# <a href="https://colab.research.google.com/github/returaj/cs6910/blob/assginment1_akash/ques4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.12.10-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 5.3 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Collecting yaspin>=1.0.0
#   Downloading yaspin-2.1.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.6-py2.py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 51.4 MB/s
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 31.6 MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.6 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.10.0.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: termcolor<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from yaspin>=1.0.0->wandb) (1.1.0)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=cba04ca92fb376e2f18f9bdf6d7e48b7a9e48874775362ea6b43278477057c33
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, yaspin, shortuuid, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.6 shortuuid-1.0.8 smmap-5.0.0 wandb-0.12.10 yaspin-2.1.0

# %%
import wandb
wandb.login()
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !ls "/content/drive/My Drive/DLASSIGNMENT"
# !python3 "/content/drive/My Drive/DLASSIGNMENT/runner.py"
# Out:
# activation_func.py  loss_func.py  optimizer.py	runner.py
# feed_forward_nn.py  measure.py	  __pycache__
# Create sweep with ID: i06ncei7
# Sweep URL: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: Agent Starting Run: n3og8vpj with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Currently logged in as: akashsainics21m003 (use `wandb login --relogin` to force relogin)
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run honest-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/n3og8vpj
# wandb: Run data is saved locally in /content/wandb/run-20220223_032236-n3og8vpj
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
#
# wandb: Waiting for W&B process to finish, PID 363... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▃▂▂▂▂█▁▇█
# wandb:         Training_Loss █▇▆▆▅▄▃▃▂▁
# wandb:   Validation_Accuracy ▁▆▇▇▇▇▁█▂▁
# wandb:       Validation_Loss █▇▆▆▅▄▃▃▂▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 6.97005
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 6.97002
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced honest-sweep-1: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/n3og8vpj
# wandb: Find logs at: ./wandb/run-20220223_032236-n3og8vpj/logs/debug.log
# wandb:
# wandb: Agent Starting Run: h6p2ggst with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run snowy-sweep-2
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/h6p2ggst
# wandb: Run data is saved locally in /content/wandb/run-20220223_032327-h6p2ggst
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 399... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ██▇▄▂▁█▇██
# wandb:         Training_Loss ▁▅▆▅▇█▄▅█▂
# wandb:   Validation_Accuracy ▁▁▂▅▇█▁▂▁▁
# wandb:       Validation_Loss ▅▂▅▄▂▁▅█▇▅
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30269
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30293
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced snowy-sweep-2: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/h6p2ggst
# wandb: Find logs at: ./wandb/run-20220223_032327-h6p2ggst/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 03i8t2fq with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run flowing-sweep-3
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/03i8t2fq
# wandb: Run data is saved locally in /content/wandb/run-20220223_032408-03i8t2fq
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 435... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▁██▂▄▂▄▆█
# wandb:         Training_Loss █▂▃▅▅▂▃▁▃▁
# wandb:   Validation_Accuracy ▁█▁▁▇▅▇▅▃▁
# wandb:       Validation_Loss █▂▃▅▄▂▃▂▄▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.31088
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.3098
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced flowing-sweep-3: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/03i8t2fq
# wandb: Find logs at: ./wandb/run-20220223_032408-03i8t2fq/logs/debug.log
# wandb:
# wandb: Agent Starting Run: g5g1yxad with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run swept-sweep-4
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/g5g1yxad
# wandb: Run data is saved locally in /content/wandb/run-20220223_033108-g5g1yxad
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 493... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▄▁▂▃
# wandb:         Training_Loss ▁▃█▄▄
# wandb:   Validation_Accuracy ▁▅█▇▆
# wandb:       Validation_Loss ▁▆█▂▇
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.0998
# wandb:         Training_Loss 2.30396
# wandb:   Validation_Accuracy 0.10183
# wandb:       Validation_Loss 2.3044
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced swept-sweep-4: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/g5g1yxad
# wandb: Find logs at: ./wandb/run-20220223_033108-g5g1yxad/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: tv9nvzu6 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run fluent-sweep-5
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/tv9nvzu6
# wandb: Run data is saved locally in /content/wandb/run-20220223_033501-tv9nvzu6
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 537... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▄▄▄▄▄▅▅▁▄█
# wandb:         Training_Loss █▇▅▄▄▃▂▂▁▁
# wandb:   Validation_Accuracy ▅▅▅▅▅▆▅▁▄█
# wandb:       Validation_Loss █▇▅▄▄▃▂▂▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.12526
# wandb:         Training_Loss 2.42632
# wandb:   Validation_Accuracy 0.12267
# wandb:       Validation_Loss 2.42634
# wandb:                epochs 10
# wandb:         test_accuracy 0.126
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced fluent-sweep-5: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/tv9nvzu6
# wandb: Find logs at: ./wandb/run-20220223_033501-tv9nvzu6/logs/debug.log
# wandb:
# wandb: Agent Starting Run: ds4g381k with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run dandy-sweep-6
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/ds4g381k
# wandb: Run data is saved locally in /content/wandb/run-20220223_033542-ds4g381k
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 575... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▇██▃█▁█▆▂█
# wandb:         Training_Loss █▅▅▃▃▆▁▇▂▄
# wandb:   Validation_Accuracy ▂▁▁▆▁█▁▃▇▁
# wandb:       Validation_Loss █▄▆▄▁▂▁▄▄█
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30267
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30301
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced dandy-sweep-6: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/ds4g381k
# wandb: Find logs at: ./wandb/run-20220223_033542-ds4g381k/logs/debug.log
# wandb:
# wandb: Agent Starting Run: yum7atxy with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run valiant-sweep-7
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/yum7atxy
# wandb: Run data is saved locally in /content/wandb/run-20220223_035135-yum7atxy
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 645... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁
# wandb:         Training_Loss █▆▄▃▁
# wandb:   Validation_Accuracy ▁▁▁▁▁
# wandb:       Validation_Loss █▆▄▃▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09974
# wandb:         Training_Loss 2.85001
# wandb:   Validation_Accuracy 0.10233
# wandb:       Validation_Loss 2.8501
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced valiant-sweep-7: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/yum7atxy
# wandb: Find logs at: ./wandb/run-20220223_035135-yum7atxy/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 4r899p0k with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run daily-sweep-8
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/4r899p0k
# wandb: Run data is saved locally in /content/wandb/run-20220223_035231-4r899p0k
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 685... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▄▁██▂█▇▆██
# wandb:         Training_Loss ▆▁█▄▃▂▂█▃█
# wandb:   Validation_Accuracy ▅█▁▁▇▁▂▃▁▁
# wandb:       Validation_Loss ▅▁▂▃▄▃█▂▆█
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30268
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30296
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced daily-sweep-8: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/4r899p0k
# wandb: Find logs at: ./wandb/run-20220223_035231-4r899p0k/logs/debug.log
# wandb:
# wandb: Agent Starting Run: c786oo80 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run still-sweep-9
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/c786oo80
# wandb: Run data is saved locally in /content/wandb/run-20220223_035357-c786oo80
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 721... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁▁▁███
# wandb:         Training_Loss █▃▂▁▁▁▁▁▁▁
# wandb:   Validation_Accuracy ███████▁▁▁
# wandb:       Validation_Loss █▃▂▁▁▁▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30258
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30265
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced still-sweep-9: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/c786oo80
# wandb: Find logs at: ./wandb/run-20220223_035357-c786oo80/logs/debug.log
# wandb:
# wandb: Agent Starting Run: z5z6aclt with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run dutiful-sweep-10
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/z5z6aclt
# wandb: Run data is saved locally in /content/wandb/run-20220223_035443-z5z6aclt
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 757... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▃▅█
# wandb:         Training_Loss █▇▆▃▁
# wandb:   Validation_Accuracy ▁▁▃▆█
# wandb:       Validation_Loss █▇▆▃▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.25394
# wandb:         Training_Loss 1.9255
# wandb:   Validation_Accuracy 0.25217
# wandb:       Validation_Loss 1.9253
# wandb:                epochs 5
# wandb:         test_accuracy 0.2545
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced dutiful-sweep-10: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/z5z6aclt
# wandb: Find logs at: ./wandb/run-20220223_035443-z5z6aclt/logs/debug.log
# wandb:
# wandb: Agent Starting Run: jgw7boqc with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run dazzling-sweep-11
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/jgw7boqc
# wandb: Run data is saved locally in /content/wandb/run-20220223_035529-jgw7boqc
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 793... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▃███▃█▂▇▁▂
# wandb:         Training_Loss █▄▂▂▁▁▁▁▁▁
# wandb:   Validation_Accuracy ▆▁▁▁▆▁▇▂█▇
# wandb:       Validation_Loss █▄▂▂▁▁▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09974
# wandb:         Training_Loss 2.40071
# wandb:   Validation_Accuracy 0.10233
# wandb:       Validation_Loss 2.40042
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced dazzling-sweep-11: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/jgw7boqc
# wandb: Find logs at: ./wandb/run-20220223_035529-jgw7boqc/logs/debug.log
# wandb:
# wandb: Agent Starting Run: qnjjz371 with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run scarlet-sweep-12
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/qnjjz371
# wandb: Run data is saved locally in /content/wandb/run-20220223_035656-qnjjz371
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 829... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ██▁▂█
# wandb:         Training_Loss ▃▁▃█▂
# wandb:   Validation_Accuracy ▁▁█▇▁
# wandb:       Validation_Loss ▅▆▁█▅
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30323
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30339
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced scarlet-sweep-12: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/qnjjz371
# wandb: Find logs at: ./wandb/run-20220223_035656-qnjjz371/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: b2erj6bo with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run easy-sweep-13
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/b2erj6bo
# wandb: Run data is saved locally in /content/wandb/run-20220223_035742-b2erj6bo
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 865... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▆██▆▁▁▂██▃
# wandb:         Training_Loss ▃▆▁▅▁▂▅▂▄█
# wandb:   Validation_Accuracy ▃▁▁▃██▇▁▁▆
# wandb:       Validation_Loss ▄█▂▅▁▂▇▄▆▇
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09996
# wandb:         Training_Loss 2.31236
# wandb:   Validation_Accuracy 0.10033
# wandb:       Validation_Loss 2.31161
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced easy-sweep-13: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/b2erj6bo
# wandb: Find logs at: ./wandb/run-20220223_035742-b2erj6bo/logs/debug.log
# wandb:
# wandb: Agent Starting Run: oairj1vb with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run leafy-sweep-14
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/oairj1vb
# wandb: Run data is saved locally in /content/wandb/run-20220223_035838-oairj1vb
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 901... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▆▇██
# wandb:         Training_Loss █▃▂▁▁
# wandb:   Validation_Accuracy ▁▆▇██
# wandb:       Validation_Loss █▃▂▂▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.86743
# wandb:         Training_Loss 0.39166
# wandb:   Validation_Accuracy 0.85017
# wandb:       Validation_Loss 0.4372
# wandb:                epochs 5
# wandb:         test_accuracy 0.8455
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced leafy-sweep-14: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/oairj1vb
# wandb: Find logs at: ./wandb/run-20220223_035838-oairj1vb/logs/debug.log
# wandb:
# wandb: Agent Starting Run: jyh18qbj with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run glowing-sweep-15
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/jyh18qbj
# wandb: Run data is saved locally in /content/wandb/run-20220223_040025-jyh18qbj
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 939... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁█
# wandb:         Training_Loss █▇▅▃▁
# wandb:   Validation_Accuracy ▆▃▁▅█
# wandb:       Validation_Loss █▇▅▃▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.11052
# wandb:         Training_Loss 22.11787
# wandb:   Validation_Accuracy 0.105
# wandb:       Validation_Loss 22.22184
# wandb:                epochs 5
# wandb:         test_accuracy 0.1112
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced glowing-sweep-15: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/jyh18qbj
# wandb: Find logs at: ./wandb/run-20220223_040025-jyh18qbj/logs/debug.log
# wandb:
# wandb: Agent Starting Run: wwtm280x with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run genial-sweep-16
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/wwtm280x
# wandb: Run data is saved locally in /content/wandb/run-20220223_040106-wwtm280x
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 973... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▆██▁█
# wandb:         Training_Loss ▁▄▆▇█
# wandb:   Validation_Accuracy ▃▁▁█▁
# wandb:       Validation_Loss ▄▇█▄▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30268
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30258
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced genial-sweep-16: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/wwtm280x
# wandb: Find logs at: ./wandb/run-20220223_040106-wwtm280x/logs/debug.log
# wandb:
# wandb: Agent Starting Run: x1unqnap with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run earthy-sweep-17
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/x1unqnap
# wandb: Run data is saved locally in /content/wandb/run-20220223_040228-x1unqnap
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1011... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▃▂█▆█▁█▁▃▁
# wandb:         Training_Loss ▂▂▂▃▂▅▂▁▃█
# wandb:   Validation_Accuracy ▆▇▁▃▁█▁█▆█
# wandb:       Validation_Loss ▁▁▂▅▃▄▁▁▃█
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.0997
# wandb:         Training_Loss 2.30822
# wandb:   Validation_Accuracy 0.10267
# wandb:       Validation_Loss 2.30914
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced earthy-sweep-17: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/x1unqnap
# wandb: Find logs at: ./wandb/run-20220223_040228-x1unqnap/logs/debug.log
# wandb:
# wandb: Agent Starting Run: o1cn8ze1 with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.5
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run sweet-sweep-18
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/o1cn8ze1
# wandb: Run data is saved locally in /content/wandb/run-20220223_040803-o1cn8ze1
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1055... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▆▆▆█▂▆█▂█
# wandb:         Training_Loss █▁▁▁▁▁▁▁▁▁
# wandb:   Validation_Accuracy █▃▃▃▁▇▃▁▇▁
# wandb:       Validation_Loss █▁▁▁▁▁▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30613
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30762
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced sweet-sweep-18: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/o1cn8ze1
# wandb: Find logs at: ./wandb/run-20220223_040803-o1cn8ze1/logs/debug.log
# wandb:
# wandb: Agent Starting Run: vst3w74i with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run desert-sweep-19
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/vst3w74i
# wandb: Run data is saved locally in /content/wandb/run-20220223_040924-vst3w74i
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1093... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▆▆██
# wandb:         Training_Loss ▃▁▁█▆
# wandb:   Validation_Accuracy █▃▃▁▁
# wandb:       Validation_Loss ▂▆█▃▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.3027
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30276
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced desert-sweep-19: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/vst3w74i
# wandb: Find logs at: ./wandb/run-20220223_040924-vst3w74i/logs/debug.log
# wandb:
# wandb: Agent Starting Run: ga0oqhr1 with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run visionary-sweep-20
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/ga0oqhr1
# wandb: Run data is saved locally in /content/wandb/run-20220223_041343-ga0oqhr1
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1137... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▃▆▇█
# wandb:         Training_Loss █▆▃▂▁
# wandb:   Validation_Accuracy ▁▃▆▇█
# wandb:       Validation_Loss █▆▃▂▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.57793
# wandb:         Training_Loss 1.18436
# wandb:   Validation_Accuracy 0.5625
# wandb:       Validation_Loss 1.21265
# wandb:                epochs 5
# wandb:         test_accuracy 0.5705
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced visionary-sweep-20: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/ga0oqhr1
# wandb: Find logs at: ./wandb/run-20220223_041343-ga0oqhr1/logs/debug.log
# wandb:
# wandb: Agent Starting Run: kqhnzi91 with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run sparkling-sweep-21
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/kqhnzi91
# wandb: Run data is saved locally in /content/wandb/run-20220223_041444-kqhnzi91
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1173... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▇▇▁█
# wandb:         Training_Loss █▇▅▃▁
# wandb:   Validation_Accuracy ▁█▇▁█
# wandb:       Validation_Loss █▇▅▃▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10007
# wandb:         Training_Loss 2.24619
# wandb:   Validation_Accuracy 0.10267
# wandb:       Validation_Loss 2.2444
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced sparkling-sweep-21: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/kqhnzi91
# wandb: Find logs at: ./wandb/run-20220223_041444-kqhnzi91/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 69qj9cm0 with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run warm-sweep-22
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/69qj9cm0
# wandb: Run data is saved locally in /content/wandb/run-20220223_041505-69qj9cm0
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1207... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▂▆▄█▄▁▃▃▂
# wandb:         Training_Loss █▇▆▅▅▄▃▂▂▁
# wandb:   Validation_Accuracy █▇▃▅▁▅█▆▆▇
# wandb:       Validation_Loss █▇▆▅▅▄▃▂▂▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.0997
# wandb:         Training_Loss 22.1723
# wandb:   Validation_Accuracy 0.10267
# wandb:       Validation_Loss 22.16887
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced warm-sweep-22: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/69qj9cm0
# wandb: Find logs at: ./wandb/run-20220223_041505-69qj9cm0/logs/debug.log
# wandb:
# wandb: Agent Starting Run: gjuron9g with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run usual-sweep-23
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/gjuron9g
# wandb: Run data is saved locally in /content/wandb/run-20220223_041843-gjuron9g
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1250... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁
# wandb:         Training_Loss █▂▅▂▁
# wandb:   Validation_Accuracy ▁▁▁▁▁
# wandb:       Validation_Loss ▁▅▄▆█
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30258
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30267
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced usual-sweep-23: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/gjuron9g
# wandb: Find logs at: ./wandb/run-20220223_041843-gjuron9g/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 4qirasbd with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.5
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run proud-sweep-24
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/4qirasbd
# wandb: Run data is saved locally in /content/wandb/run-20220223_041944-4qirasbd
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1290... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▄███▅▂▁
# wandb:         Training_Loss █▆▄▃▂▁▁▁▁▁
# wandb:   Validation_Accuracy ▁▁▁▄███▅▂▁
# wandb:       Validation_Loss █▆▄▃▂▁▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.0998
# wandb:         Training_Loss 5.47339
# wandb:   Validation_Accuracy 0.10183
# wandb:       Validation_Loss 5.47494
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced proud-sweep-24: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/4qirasbd
# wandb: Find logs at: ./wandb/run-20220223_041944-4qirasbd/logs/debug.log
# wandb:
# wandb: Agent Starting Run: u9hjtr2k with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run fearless-sweep-25
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/u9hjtr2k
# wandb: Run data is saved locally in /content/wandb/run-20220223_042044-u9hjtr2k
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1326... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁██▅▆
# wandb:         Training_Loss █▃▁▁▁
# wandb:   Validation_Accuracy ▁██▅▆
# wandb:       Validation_Loss █▃▁▁▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.48569
# wandb:         Training_Loss 1.30115
# wandb:   Validation_Accuracy 0.47533
# wandb:       Validation_Loss 1.34636
# wandb:                epochs 5
# wandb:         test_accuracy 0.4805
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced fearless-sweep-25: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/u9hjtr2k
# wandb: Find logs at: ./wandb/run-20220223_042044-u9hjtr2k/logs/debug.log
# wandb:
# wandb: Agent Starting Run: dr8zc87p with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# ...
# wandb: Run data is saved locally in /content/wandb/run-20220223_051418-68qbpulj
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2736... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▆█▁█▆
# wandb:         Training_Loss ▁▅▃▂█
# wandb:   Validation_Accuracy ▃▁█▁▃
# wandb:       Validation_Loss ▁█▃▃█
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10024
# wandb:         Training_Loss 2.31428
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 2.31335
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced glamorous-sweep-62: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/68qbpulj
# wandb: Find logs at: ./wandb/run-20220223_051418-68qbpulj/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: nacmiehq with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run daily-sweep-63
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/nacmiehq
# wandb: Run data is saved locally in /content/wandb/run-20220223_051529-nacmiehq
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2774... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▆▃▂▂▂▄▆▇█
# wandb:         Training_Loss █▄▄▃▃▂▁▁▁▁
# wandb:   Validation_Accuracy ▁▆▃▂▂▂▄▆▇█
# wandb:       Validation_Loss █▅▄▃▃▂▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.75039
# wandb:         Training_Loss 1.33818
# wandb:   Validation_Accuracy 0.73883
# wandb:       Validation_Loss 1.35816
# wandb:                epochs 10
# wandb:         test_accuracy 0.7393
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced daily-sweep-63: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/nacmiehq
# wandb: Find logs at: ./wandb/run-20220223_051529-nacmiehq/logs/debug.log
# wandb:
# wandb: Agent Starting Run: dsn4imn7 with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run azure-sweep-64
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/dsn4imn7
# wandb: Run data is saved locally in /content/wandb/run-20220223_051736-dsn4imn7
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2812... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ████████▇▁
# wandb:         Training_Loss █▇▆▆▅▄▃▃▂▁
# wandb:   Validation_Accuracy █████████▁
# wandb:       Validation_Loss █▇▆▆▅▄▃▃▂▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09694
# wandb:         Training_Loss 2.2992
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 2.2991
# wandb:                epochs 10
# wandb:         test_accuracy 0.0979
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced azure-sweep-64: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/dsn4imn7
# wandb: Find logs at: ./wandb/run-20220223_051736-dsn4imn7/logs/debug.log
# wandb:
# wandb: Agent Starting Run: hsyzhti1 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run pious-sweep-65
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/hsyzhti1
# wandb: Run data is saved locally in /content/wandb/run-20220223_051813-hsyzhti1
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2848... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▆▁▆█▆▆▆▆▆▆
# wandb:         Training_Loss █▆▄▃▃▂▂▁▁▁
# wandb:   Validation_Accuracy ▇▁▆█▆▆▆▆▆▆
# wandb:       Validation_Loss █▆▄▃▃▂▂▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.33642
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.33645
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced pious-sweep-65: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/hsyzhti1
# wandb: Find logs at: ./wandb/run-20220223_051813-hsyzhti1/logs/debug.log
# wandb:
# wandb: Agent Starting Run: klrsblp1 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run stilted-sweep-66
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/klrsblp1
# wandb: Run data is saved locally in /content/wandb/run-20220223_052046-klrsblp1
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2890... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▂██▁▂
# wandb:         Training_Loss █▅▃▂▁
# wandb:   Validation_Accuracy ▇▁▁█▇
# wandb:       Validation_Loss █▅▃▂▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.0997
# wandb:         Training_Loss 2.9095
# wandb:   Validation_Accuracy 0.10267
# wandb:       Validation_Loss 2.90948
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced stilted-sweep-66: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/klrsblp1
# wandb: Find logs at: ./wandb/run-20220223_052046-klrsblp1/logs/debug.log
# wandb:
# wandb: Agent Starting Run: ckgmsr6w with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run usual-sweep-67
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/ckgmsr6w
# wandb: Run data is saved locally in /content/wandb/run-20220223_052125-ckgmsr6w
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2926... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁
# wandb:         Training_Loss █▆▄▂▁
# wandb:   Validation_Accuracy ▁▁▁▁▁
# wandb:       Validation_Loss ▁▃▅▇█
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30258
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30262
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced usual-sweep-67: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/ckgmsr6w
# wandb: Find logs at: ./wandb/run-20220223_052125-ckgmsr6w/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: j4koa8rl with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run zany-sweep-68
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/j4koa8rl
# wandb: Run data is saved locally in /content/wandb/run-20220223_052211-j4koa8rl
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2962... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▃▁█▃▆
# wandb:         Training_Loss █▆▅▃▁
# wandb:   Validation_Accuracy ▆█▁▆▃
# wandb:       Validation_Loss █▆▅▃▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10024
# wandb:         Training_Loss 12.05696
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 12.05735
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced zany-sweep-68: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/j4koa8rl
# wandb: Find logs at: ./wandb/run-20220223_052211-j4koa8rl/logs/debug.log
# wandb:
# wandb: Agent Starting Run: a1uhrusb with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run smart-sweep-69
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/a1uhrusb
# wandb: Run data is saved locally in /content/wandb/run-20220223_052242-a1uhrusb
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2996... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▃▂▃▃▄▄▄▄█
# wandb:         Training_Loss ██▇▇▆▆▅▄▃▁
# wandb:   Validation_Accuracy ▁▄▂▃▃▃▄▄▄█
# wandb:       Validation_Loss ██▇▇▆▆▅▄▃▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.12789
# wandb:         Training_Loss 2.29553
# wandb:   Validation_Accuracy 0.13183
# wandb:       Validation_Loss 2.29544
# wandb:                epochs 10
# wandb:         test_accuracy 0.1246
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced smart-sweep-69: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/a1uhrusb
# wandb: Find logs at: ./wandb/run-20220223_052242-a1uhrusb/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: bib40otn with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0.5
# wandb: 	weight_init: random
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run honest-sweep-70
# wandb: ⭐️ View project at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/sweeps/i06ncei7
# wandb: 🚀 View run at https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/bib40otn
# wandb: Run data is saved locally in /content/wandb/run-20220223_052338-bib40otn
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 3032... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▄▁████▇▄▄
# wandb:         Training_Loss ▃▂█▅▃▅▂▄▃▁
# wandb:   Validation_Accuracy ▁▅█▁▁▁▁▂▅▅
# wandb:       Validation_Loss █▂▄▃▅▂▅▁▂▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09996
# wandb:         Training_Loss 2.3026
# wandb:   Validation_Accuracy 0.10033
# wandb:       Validation_Loss 2.30264
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced honest-sweep-70: https://wandb.ai/cs21m003_cs21d406/CS6910_ASSIGNMENT/runs/bib40otn
# wandb: Find logs at: ./wandb/run-20220223_052338-bib40otn/logs/debug.log
# wandb:
