# %% [markdown]
# <a href="https://colab.research.google.com/github/returaj/cs6910/blob/assginment1_akash/ques4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.12.10-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 5.2 MB/s
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 50.2 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting yaspin>=1.0.0
#   Downloading yaspin-2.1.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.5-py2.py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 49.7 MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.10.0.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.6 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: termcolor<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from yaspin>=1.0.0->wandb) (1.1.0)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=404fb33c71212ca7b00eae19705a7c0131ff8937282bce404f3bb24be8eb7ff5
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, yaspin, shortuuid, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.5 shortuuid-1.0.8 smmap-5.0.0 wandb-0.12.10 yaspin-2.1.0

# %%
import wandb
wandb.login()
# Out:
# wandb: Currently logged in as: akashsainics21m003 (use `wandb login --relogin` to force relogin)
# True

# %%
# !ls "/content/drive/My Drive/DLASSIGNMENT"
# !python3 "/content/drive/My Drive/DLASSIGNMENT/runner.py"
# Out:
# activation_func.py  loss_func.py  optimizer.py	runner.py
# feed_forward_nn.py  measure.py	  __pycache__
# Create sweep with ID: kz23iyez
# Sweep URL: https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: Agent Starting Run: 3ak9k4uy with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.5
# wandb: 	weight_init: random
# wandb: Currently logged in as: akashsainics21m003 (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run twilight-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/3ak9k4uy
# wandb: Run data is saved locally in /content/wandb/run-20220221_082505-3ak9k4uy
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4260... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▂▇██▁▇▆▇▂▃
# wandb:         Training_Loss █▂▂▁▁▁▁▁▁▁
# wandb:   Validation_Accuracy ▇▂▁▁█▂▃▂▇▆
# wandb:       Validation_Loss █▃▂▂▁▂▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.0998
# wandb:         Training_Loss 2.30264
# wandb:   Validation_Accuracy 0.10183
# wandb:       Validation_Loss 2.30261
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced twilight-sweep-1: https://wandb.ai/akashsainics21m003/cs6910_4/runs/3ak9k4uy
# wandb: Find logs at: ./wandb/run-20220221_082505-3ak9k4uy/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 72kw5zcx with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.5
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run wise-sweep-2
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/72kw5zcx
# wandb: Run data is saved locally in /content/wandb/run-20220221_082855-72kw5zcx
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4344... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ██▁▁▇
# wandb:         Training_Loss █▁▁▁▁
# wandb:   Validation_Accuracy ▁▁██▂
# wandb:       Validation_Loss █▁▁▁▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10024
# wandb:         Training_Loss 2.31388
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 2.31725
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced wise-sweep-2: https://wandb.ai/akashsainics21m003/cs6910_4/runs/72kw5zcx
# wandb: Find logs at: ./wandb/run-20220221_082855-72kw5zcx/logs/debug.log
# wandb:
# wandb: Agent Starting Run: q515s3qk with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run genial-sweep-3
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/q515s3qk
# wandb: Run data is saved locally in /content/wandb/run-20220221_083017-q515s3qk
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4396... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▁▇▄▁
# wandb:         Training_Loss ▄█▃▃▁
# wandb:   Validation_Accuracy ▁█▂▅█
# wandb:       Validation_Loss █▃▁▄▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09954
# wandb:         Training_Loss 2.30267
# wandb:   Validation_Accuracy 0.10417
# wandb:       Validation_Loss 2.30272
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced genial-sweep-3: https://wandb.ai/akashsainics21m003/cs6910_4/runs/q515s3qk
# wandb: Find logs at: ./wandb/run-20220221_083017-q515s3qk/logs/debug.log
# wandb:
# wandb: Agent Starting Run: tgrxu0sj with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run colorful-sweep-4
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/tgrxu0sj
# wandb: Run data is saved locally in /content/wandb/run-20220221_083052-tgrxu0sj
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4438... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▃▇▇█
# wandb:         Training_Loss ██▄▂▁
# wandb:   Validation_Accuracy ▁▃▇▇█
# wandb:       Validation_Loss ██▄▂▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.23265
# wandb:         Training_Loss 1.66887
# wandb:   Validation_Accuracy 0.22367
# wandb:       Validation_Loss 1.66793
# wandb:                epochs 5
# wandb:         test_accuracy 0.2342
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced colorful-sweep-4: https://wandb.ai/akashsainics21m003/cs6910_4/runs/tgrxu0sj
# wandb: Find logs at: ./wandb/run-20220221_083052-tgrxu0sj/logs/debug.log
# wandb:
# wandb: Agent Starting Run: zra4dn25 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run sage-sweep-5
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/zra4dn25
# wandb: Run data is saved locally in /content/wandb/run-20220221_083138-zra4dn25
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4484... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁██▁
# wandb:         Training_Loss █▅▂▁▂
# wandb:   Validation_Accuracy ██▁▁█
# wandb:       Validation_Loss ▁▃▅▆█
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10031
# wandb:         Training_Loss 2.30258
# wandb:   Validation_Accuracy 0.09717
# wandb:       Validation_Loss 2.3027
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced sage-sweep-5: https://wandb.ai/akashsainics21m003/cs6910_4/runs/zra4dn25
# wandb: Find logs at: ./wandb/run-20220221_083138-zra4dn25/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 0ogqirl9 with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run polished-sweep-6
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/0ogqirl9
# wandb: Run data is saved locally in /content/wandb/run-20220221_083432-0ogqirl9
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4556... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁██▆▁
# wandb:         Training_Loss ▃▆▄▁█
# wandb:   Validation_Accuracy █▁▁▃█
# wandb:       Validation_Loss ▁█▁▁▆
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09974
# wandb:         Training_Loss 2.30272
# wandb:   Validation_Accuracy 0.10233
# wandb:       Validation_Loss 2.30291
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced polished-sweep-6: https://wandb.ai/akashsainics21m003/cs6910_4/runs/0ogqirl9
# wandb: Find logs at: ./wandb/run-20220221_083432-0ogqirl9/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 2kb94h10 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run upbeat-sweep-7
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/2kb94h10
# wandb: Run data is saved locally in /content/wandb/run-20220221_083549-2kb94h10
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4606... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▂████████
# wandb:         Training_Loss █▇▁▁▁▁▁▁▁▁
# wandb:   Validation_Accuracy ▁▂████████
# wandb:       Validation_Loss █▇▁▁▁▁▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.8448
# wandb:         Training_Loss 0.57367
# wandb:   Validation_Accuracy 0.828
# wandb:       Validation_Loss 0.62243
# wandb:                epochs 10
# wandb:         test_accuracy 0.8231
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced upbeat-sweep-7: https://wandb.ai/akashsainics21m003/cs6910_4/runs/2kb94h10
# wandb: Find logs at: ./wandb/run-20220221_083549-2kb94h10/logs/debug.log
# wandb:
# wandb: Agent Starting Run: cwmjcxqq with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run eager-sweep-8
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/cwmjcxqq
# wandb: Run data is saved locally in /content/wandb/run-20220221_083832-cwmjcxqq
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4682... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁
# wandb:         Training_Loss █▅▂▁▁
# wandb:   Validation_Accuracy ▁▁▁▁▁
# wandb:       Validation_Loss ▁▄▆▇█
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30258
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30267
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced eager-sweep-8: https://wandb.ai/akashsainics21m003/cs6910_4/runs/cwmjcxqq
# wandb: Find logs at: ./wandb/run-20220221_083832-cwmjcxqq/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 7t7svjks with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run treasured-sweep-9
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/7t7svjks
# wandb: Run data is saved locally in /content/wandb/run-20220221_083943-7t7svjks
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4732... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ██▆▆▁
# wandb:         Training_Loss █▂▂▁▁
# wandb:   Validation_Accuracy ▁▁▃▃█
# wandb:       Validation_Loss █▂▂▁▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.0997
# wandb:         Training_Loss 7.15126
# wandb:   Validation_Accuracy 0.10267
# wandb:       Validation_Loss 7.15119
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced treasured-sweep-9: https://wandb.ai/akashsainics21m003/cs6910_4/runs/7t7svjks
# wandb: Find logs at: ./wandb/run-20220221_083943-7t7svjks/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 1n3e7f7t with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run lilac-sweep-10
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/1n3e7f7t
# wandb: Run data is saved locally in /content/wandb/run-20220221_084009-1n3e7f7t
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4770... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▃▄▆█
# wandb:         Training_Loss █▆▅▃▁
# wandb:   Validation_Accuracy ▁▃▄▆█
# wandb:       Validation_Loss █▆▅▃▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.6058
# wandb:         Training_Loss 1.13267
# wandb:   Validation_Accuracy 0.60017
# wandb:       Validation_Loss 1.13754
# wandb:                epochs 5
# wandb:         test_accuracy 0.6042
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced lilac-sweep-10: https://wandb.ai/akashsainics21m003/cs6910_4/runs/1n3e7f7t
# wandb: Find logs at: ./wandb/run-20220221_084009-1n3e7f7t/logs/debug.log
# wandb:
# wandb: Agent Starting Run: s2xjhi14 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.5
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run trim-sweep-11
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/s2xjhi14
# wandb: Run data is saved locally in /content/wandb/run-20220221_084035-s2xjhi14
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4812... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁
# wandb:         Training_Loss █▆▄▂▁
# wandb:   Validation_Accuracy ▁▁▁▁▁
# wandb:       Validation_Loss █▆▄▂▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10024
# wandb:         Training_Loss 2253.1103
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 2253.11214
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced trim-sweep-11: https://wandb.ai/akashsainics21m003/cs6910_4/runs/s2xjhi14
# wandb: Find logs at: ./wandb/run-20220221_084035-s2xjhi14/logs/debug.log
# wandb:
# wandb: Agent Starting Run: vgy1wtc7 with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run revived-sweep-12
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/vgy1wtc7
# wandb: Run data is saved locally in /content/wandb/run-20220221_084126-vgy1wtc7
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4858... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▁▁▁▁
# wandb:         Training_Loss █▆▄▃▁
# wandb:   Validation_Accuracy ▁████
# wandb:       Validation_Loss █▆▄▃▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10024
# wandb:         Training_Loss 2.3013
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 2.30128
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced revived-sweep-12: https://wandb.ai/akashsainics21m003/cs6910_4/runs/vgy1wtc7
# wandb: Find logs at: ./wandb/run-20220221_084126-vgy1wtc7/logs/debug.log
# wandb:
# wandb: Agent Starting Run: cblptfa9 with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.5
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run swift-sweep-13
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/cblptfa9
# wandb: Run data is saved locally in /content/wandb/run-20220221_084212-cblptfa9
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4900... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▂█▆█▁▂█▂▃▂
# wandb:         Training_Loss ▄▅▂▇█▃▁▃▁▃
# wandb:   Validation_Accuracy ▇▁▃▁█▇▁▇▆▇
# wandb:       Validation_Loss ▃▄▂█▆▃▁▃▂▃
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09974
# wandb:         Training_Loss 2.30458
# wandb:   Validation_Accuracy 0.10233
# wandb:       Validation_Loss 2.30481
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced swift-sweep-13: https://wandb.ai/akashsainics21m003/cs6910_4/runs/cblptfa9
# wandb: Find logs at: ./wandb/run-20220221_084212-cblptfa9/logs/debug.log
# wandb:
# wandb: Agent Starting Run: lc88esv6 with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run zany-sweep-14
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/lc88esv6
# wandb: Run data is saved locally in /content/wandb/run-20220221_084349-lc88esv6
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 4956... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▁█▁▁▆█▁▆▁
# wandb:         Training_Loss ▃▃▃█▂▁▅██▄
# wandb:   Validation_Accuracy ▁█▁██▃▁█▃█
# wandb:       Validation_Loss ▃▂▂▇▁▁▅▆█▂
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.0997
# wandb:         Training_Loss 2.31328
# wandb:   Validation_Accuracy 0.10267
# wandb:       Validation_Loss 2.3101
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced zany-sweep-14: https://wandb.ai/akashsainics21m003/cs6910_4/runs/lc88esv6
# wandb: Find logs at: ./wandb/run-20220221_084349-lc88esv6/logs/debug.log
# wandb:
# wandb: Agent Starting Run: axulvvml with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run smart-sweep-15
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/axulvvml
# wandb: Run data is saved locally in /content/wandb/run-20220221_084658-axulvvml
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5032... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▁█▂▆█▃▁▂█
# wandb:         Training_Loss █▆▄▅▁▄▆▃▄▁
# wandb:   Validation_Accuracy ▁█▁▇▃▁▆█▇▁
# wandb:       Validation_Loss █▂█▁▁▅▇▂▃▃
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30306
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30372
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced smart-sweep-15: https://wandb.ai/akashsainics21m003/cs6910_4/runs/axulvvml
# wandb: Find logs at: ./wandb/run-20220221_084658-axulvvml/logs/debug.log
# wandb:
# wandb: Agent Starting Run: go0lpgr6 with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run brisk-sweep-16
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/go0lpgr6
# wandb: Run data is saved locally in /content/wandb/run-20220221_084926-go0lpgr6
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5100... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁
# wandb:         Training_Loss █▆▄▃▁
# wandb:   Validation_Accuracy ▁▁▁▁▁
# wandb:       Validation_Loss █▆▄▃▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 475695565.52985
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 475695565.52994
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced brisk-sweep-16: https://wandb.ai/akashsainics21m003/cs6910_4/runs/go0lpgr6
# wandb: Find logs at: ./wandb/run-20220221_084926-go0lpgr6/logs/debug.log
# wandb:
# wandb: Agent Starting Run: so5rh4fk with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run still-sweep-17
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/so5rh4fk
# wandb: Run data is saved locally in /content/wandb/run-20220221_085012-so5rh4fk
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5144... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▃█
# wandb:         Training_Loss █▇▆▅▁
# wandb:   Validation_Accuracy ▁▁▁▃█
# wandb:       Validation_Loss █▇▆▄▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.43587
# wandb:         Training_Loss 13.58752
# wandb:   Validation_Accuracy 0.4205
# wandb:       Validation_Loss 13.87376
# wandb:                epochs 5
# wandb:         test_accuracy 0.433
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced still-sweep-17: https://wandb.ai/akashsainics21m003/cs6910_4/runs/so5rh4fk
# wandb: Find logs at: ./wandb/run-20220221_085012-so5rh4fk/logs/debug.log
# wandb:
# wandb: Agent Starting Run: j6g8a6f0 with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run frosty-sweep-18
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/j6g8a6f0
# wandb: Run data is saved locally in /content/wandb/run-20220221_085103-j6g8a6f0
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5190... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▇▇▁▁▁▂▂▃▄█
# wandb:         Training_Loss █▇▇▆▆▅▄▃▂▁
# wandb:   Validation_Accuracy ▁▁▇▇▇▇▇▇▇█
# wandb:       Validation_Loss █▇▇▆▆▅▄▃▂▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10069
# wandb:         Training_Loss 2.25801
# wandb:   Validation_Accuracy 0.10383
# wandb:       Validation_Loss 2.25681
# wandb:                epochs 10
# wandb:         test_accuracy 0.1007
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced frosty-sweep-18: https://wandb.ai/akashsainics21m003/cs6910_4/runs/j6g8a6f0
# wandb: Find logs at: ./wandb/run-20220221_085103-j6g8a6f0/logs/debug.log
# wandb:
# wandb: Agent Starting Run: z7p8u4en with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run bright-sweep-19
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/z7p8u4en
# wandb: Run data is saved locally in /content/wandb/run-20220221_085144-z7p8u4en
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5234... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁██▇▆
# wandb:         Training_Loss ▂▆▁█▄
# wandb:   Validation_Accuracy █▁▁▂▃
# wandb:       Validation_Loss ▁▆▅█▅
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10024
# wandb:         Training_Loss 2.30385
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 2.30413
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced bright-sweep-19: https://wandb.ai/akashsainics21m003/cs6910_4/runs/z7p8u4en
# wandb: Find logs at: ./wandb/run-20220221_085144-z7p8u4en/logs/debug.log
# wandb:
# wandb: Agent Starting Run: zx0c7d8s with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run major-sweep-20
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/zx0c7d8s
# wandb: Run data is saved locally in /content/wandb/run-20220221_085458-zx0c7d8s
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5310... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▆▆▁▆█▅█▆█▁
# wandb:         Training_Loss ▆█▆▄▃▄▁▄▂▄
# wandb:   Validation_Accuracy ▃▃█▃▁▄▁▃▁█
# wandb:       Validation_Loss ██▁▆▅▇▄▃▆▂
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09996
# wandb:         Training_Loss 2.30261
# wandb:   Validation_Accuracy 0.10033
# wandb:       Validation_Loss 2.30264
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced major-sweep-20: https://wandb.ai/akashsainics21m003/cs6910_4/runs/zx0c7d8s
# wandb: Find logs at: ./wandb/run-20220221_085458-zx0c7d8s/logs/debug.log
# wandb:
# wandb: Agent Starting Run: sp9z8g6g with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run silver-sweep-21
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/sp9z8g6g
# wandb: Run data is saved locally in /content/wandb/run-20220221_085610-sp9z8g6g
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5360... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁█▄▄█▁▁█▂▂
# wandb:         Training_Loss ▁█▆▇▅▂▃▅▂▃
# wandb:   Validation_Accuracy █▁▅▅▁██▁▇▇
# wandb:       Validation_Loss ▁█▆█▆▂▂▅▂▃
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.0997
# wandb:         Training_Loss 2.31154
# wandb:   Validation_Accuracy 0.10267
# wandb:       Validation_Loss 2.31248
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced silver-sweep-21: https://wandb.ai/akashsainics21m003/cs6910_4/runs/sp9z8g6g
# wandb: Find logs at: ./wandb/run-20220221_085610-sp9z8g6g/logs/debug.log
# wandb:
# wandb: Agent Starting Run: ko1uj48a with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run kind-sweep-22
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/ko1uj48a
# wandb: Run data is saved locally in /content/wandb/run-20220221_085918-ko1uj48a
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5436... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▇▁▃█▁
# wandb:         Training_Loss ▃█▇▁▁
# wandb:   Validation_Accuracy ▂█▆▁█
# wandb:       Validation_Loss █▁▄▅▇
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09954
# wandb:         Training_Loss 2.3036
# wandb:   Validation_Accuracy 0.10417
# wandb:       Validation_Loss 2.30367
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced kind-sweep-22: https://wandb.ai/akashsainics21m003/cs6910_4/runs/ko1uj48a
# wandb: Find logs at: ./wandb/run-20220221_085918-ko1uj48a/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 8wexn4ma with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run likely-sweep-23
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/8wexn4ma
# wandb: Run data is saved locally in /content/wandb/run-20220221_090005-8wexn4ma
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5482... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▃▁▁█▃█▆███
# wandb:         Training_Loss ▅▁▄▁▂▃█▃▅▅
# wandb:   Validation_Accuracy ▆██▁▆▁▃▁▁▁
# wandb:       Validation_Loss ▃▁▃▄▃▇█▃▇▇
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30421
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30463
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced likely-sweep-23: https://wandb.ai/akashsainics21m003/cs6910_4/runs/8wexn4ma
# wandb: Find logs at: ./wandb/run-20220221_090005-8wexn4ma/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 4oziob5c with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run elated-sweep-24
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/4oziob5c
# wandb: Run data is saved locally in /content/wandb/run-20220221_090243-4oziob5c
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5552... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▅▇██
# wandb:         Training_Loss █▄▂▁▁
# wandb:   Validation_Accuracy ▁▅▇▇█
# wandb:       Validation_Loss █▄▂▁▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.86919
# wandb:         Training_Loss 0.38567
# wandb:   Validation_Accuracy 0.85867
# wandb:       Validation_Loss 0.44515
# wandb:                epochs 5
# wandb:         test_accuracy 0.8498
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced elated-sweep-24: https://wandb.ai/akashsainics21m003/cs6910_4/runs/4oziob5c
# wandb: Find logs at: ./wandb/run-20220221_090243-4oziob5c/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 93tjuwpz with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run avid-sweep-25
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/93tjuwpz
# wandb: Run data is saved locally in /content/wandb/run-20220221_090410-93tjuwpz
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5604... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▁▄██
# wandb:         Training_Loss ▄▂█▄▁
# wandb:   Validation_Accuracy ▁█▅▁▁
# wandb:       Validation_Loss ▄▂█▄▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09996
# wandb:         Training_Loss 2.30412
# wandb:   Validation_Accuracy 0.10033
# wandb:       Validation_Loss 2.30346
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced avid-sweep-25: https://wandb.ai/akashsainics21m003/cs6910_4/runs/93tjuwpz
# wandb: Find logs at: ./wandb/run-20220221_090410-93tjuwpz/logs/debug.log
# wandb:
# wandb: Agent Starting Run: r938ye3u with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run tough-sweep-26
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/r938ye3u
# wandb: Run data is saved locally in /content/wandb/run-20220221_090526-r938ye3u
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5656... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▃▄▇█
# wandb:         Training_Loss █▆▅▂▁
# wandb:   Validation_Accuracy ▁▃▅▇█
# wandb:       Validation_Loss █▆▅▂▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.67526
# wandb:         Training_Loss 0.91371
# wandb:   Validation_Accuracy 0.664
# wandb:       Validation_Loss 0.92491
# wandb:                epochs 5
# wandb:         test_accuracy 0.6673
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced tough-sweep-26: https://wandb.ai/akashsainics21m003/cs6910_4/runs/r938ye3u
# wandb: Find logs at: ./wandb/run-20220221_090526-r938ye3u/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 5wutgxgw with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run decent-sweep-27
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/5wutgxgw
# wandb: Run data is saved locally in /content/wandb/run-20220221_090602-5wutgxgw
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5700... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▂▄▄▅▆▇██
# wandb:         Training_Loss █▇▆▄▃▃▂▂▁▁
# wandb:   Validation_Accuracy ▁▁▂▄▄▅▆▇██
# wandb:       Validation_Loss █▇▆▄▃▃▂▂▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.7363
# wandb:         Training_Loss 0.72425
# wandb:   Validation_Accuracy 0.72267
# wandb:       Validation_Loss 0.74715
# wandb:                epochs 10
# wandb:         test_accuracy 0.722
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced decent-sweep-27: https://wandb.ai/akashsainics21m003/cs6910_4/runs/5wutgxgw
# wandb: Find logs at: ./wandb/run-20220221_090602-5wutgxgw/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 4y0go2ov with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run unique-sweep-28
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/4y0go2ov
# wandb: Run data is saved locally in /content/wandb/run-20220221_091007-4y0go2ov
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5788... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▂▂█▂█▂▂▆▂
# wandb:         Training_Loss █▂▁▂▄▁▅▃▅▅
# wandb:   Validation_Accuracy █▇▇▁▇▁▇▇▃▇
# wandb:       Validation_Loss █▁▂▁▆▂▅▃▆█
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.0997
# wandb:         Training_Loss 2.30405
# wandb:   Validation_Accuracy 0.10267
# wandb:       Validation_Loss 2.30429
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced unique-sweep-28: https://wandb.ai/akashsainics21m003/cs6910_4/runs/4y0go2ov
# wandb: Find logs at: ./wandb/run-20220221_091007-4y0go2ov/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: c9oapah1 with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run sweepy-sweep-29
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/c9oapah1
# wandb: Run data is saved locally in /content/wandb/run-20220221_091320-c9oapah1
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 5866... (success).
# ...
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▂▃▆▇▇▇█▆█
# wandb:         Training_Loss █▅▄▃▂▂▂▁▁▁
# wandb:   Validation_Accuracy ▁▂▃▇▇▇▇▇▆█
# wandb:       Validation_Loss █▅▄▃▂▂▂▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.84972
# wandb:         Training_Loss 0.81037
# wandb:   Validation_Accuracy 0.837
# wandb:       Validation_Loss 0.87198
# wandb:                epochs 10
# wandb:         test_accuracy 0.8299
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced rare-sweep-61: https://wandb.ai/akashsainics21m003/cs6910_4/runs/574svbry
# wandb: Find logs at: ./wandb/run-20220221_101912-574svbry/logs/debug.log
# wandb:
# wandb: Agent Starting Run: l6fueyur with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run efficient-sweep-62
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/l6fueyur
# wandb: Run data is saved locally in /content/wandb/run-20220221_102034-l6fueyur
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 7202... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁█▃▂▁
# wandb:         Training_Loss █▇▁▁▁
# wandb:   Validation_Accuracy ▁█▂▁▁
# wandb:       Validation_Loss █▇▁▁▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10083
# wandb:         Training_Loss 2.32843
# wandb:   Validation_Accuracy 0.1035
# wandb:       Validation_Loss 2.32168
# wandb:                epochs 5
# wandb:         test_accuracy 0.1012
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced efficient-sweep-62: https://wandb.ai/akashsainics21m003/cs6910_4/runs/l6fueyur
# wandb: Find logs at: ./wandb/run-20220221_102034-l6fueyur/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: wyrti0hf with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run mild-sweep-63
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/wyrti0hf
# wandb: Run data is saved locally in /content/wandb/run-20220221_102227-wyrti0hf
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 7240... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▇▇▇▃▂█▁▆▆
# wandb:         Training_Loss ▆▂▅▇▆▁▁▅█▃
# wandb:   Validation_Accuracy ▁▂▂▂▆▇▁█▃▃
# wandb:       Validation_Loss █▄▆▅▂▁▁▃█▃
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10024
# wandb:         Training_Loss 2.30319
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 2.30342
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced mild-sweep-63: https://wandb.ai/akashsainics21m003/cs6910_4/runs/wyrti0hf
# wandb: Find logs at: ./wandb/run-20220221_102227-wyrti0hf/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 59lld86p with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run denim-sweep-64
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/59lld86p
# wandb: Run data is saved locally in /content/wandb/run-20220221_102526-59lld86p
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 7280... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▃▆██
# wandb:         Training_Loss █▆▃▂▁
# wandb:   Validation_Accuracy ▁▃▆██
# wandb:       Validation_Loss █▆▃▂▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.71848
# wandb:         Training_Loss 0.71757
# wandb:   Validation_Accuracy 0.71233
# wandb:       Validation_Loss 0.73589
# wandb:                epochs 5
# wandb:         test_accuracy 0.71
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced denim-sweep-64: https://wandb.ai/akashsainics21m003/cs6910_4/runs/59lld86p
# wandb: Find logs at: ./wandb/run-20220221_102526-59lld86p/logs/debug.log
# wandb:
# wandb: Agent Starting Run: px1rcyhq with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run sage-sweep-65
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/px1rcyhq
# wandb: Run data is saved locally in /content/wandb/run-20220221_102602-px1rcyhq
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 7314... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▆▂▁▂▂▂█▄▁█
# wandb:         Training_Loss ▂▁▃▁█▃▃▄▅▇
# wandb:   Validation_Accuracy ▃▇█▇▇▇▁▅█▁
# wandb:       Validation_Loss ▃▂▃▁▂▁▄▁▄█
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.3044
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30553
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced sage-sweep-65: https://wandb.ai/akashsainics21m003/cs6910_4/runs/px1rcyhq
# wandb: Find logs at: ./wandb/run-20220221_102602-px1rcyhq/logs/debug.log
# wandb:
# wandb: Agent Starting Run: b2f9dwqb with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run wandering-sweep-66
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/b2f9dwqb
# wandb: Run data is saved locally in /content/wandb/run-20220221_102845-b2f9dwqb
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 7354... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▄█▇▆
# wandb:         Training_Loss █▅▁▁▂
# wandb:   Validation_Accuracy ▁▄█▇▆
# wandb:       Validation_Loss █▅▁▁▂
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.24976
# wandb:         Training_Loss 15.68206
# wandb:   Validation_Accuracy 0.25517
# wandb:       Validation_Loss 15.63111
# wandb:                epochs 5
# wandb:         test_accuracy 0.2464
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced wandering-sweep-66: https://wandb.ai/akashsainics21m003/cs6910_4/runs/b2f9dwqb
# wandb: Find logs at: ./wandb/run-20220221_102845-b2f9dwqb/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 22jsgxeh with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run grateful-sweep-67
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/22jsgxeh
# wandb: Run data is saved locally in /content/wandb/run-20220221_102911-22jsgxeh
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 7388... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▁█▆▂██▂▇▇
# wandb:         Training_Loss ▂▆█▁▇▃▃▂▁▅
# wandb:   Validation_Accuracy ▁█▁▃▇▁▁▇▂▂
# wandb:       Validation_Loss ▃▁█▂▄▄▆▁▂▄
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10031
# wandb:         Training_Loss 2.30413
# wandb:   Validation_Accuracy 0.09717
# wandb:       Validation_Loss 2.30427
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced grateful-sweep-67: https://wandb.ai/akashsainics21m003/cs6910_4/runs/22jsgxeh
# wandb: Find logs at: ./wandb/run-20220221_102911-22jsgxeh/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 68js646i with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run quiet-sweep-68
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/68js646i
# wandb: Run data is saved locally in /content/wandb/run-20220221_103018-68js646i
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 7426... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁▁▁▁▁▁
# wandb:         Training_Loss █▁▁▁▁▁▁▁▁▁
# wandb:   Validation_Accuracy ▁▁▁▁▁▁▁▁▁▁
# wandb:       Validation_Loss █▁▁▁▁▁▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30258
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.3027
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced quiet-sweep-68: https://wandb.ai/akashsainics21m003/cs6910_4/runs/68js646i
# wandb: Find logs at: ./wandb/run-20220221_103018-68js646i/logs/debug.log
# wandb:
# wandb: Agent Starting Run: p70fmpkj with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run divine-sweep-69
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/p70fmpkj
# wandb: Run data is saved locally in /content/wandb/run-20220221_103125-p70fmpkj
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 7462... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▂▁▁█▆
# wandb:         Training_Loss █▄▂▁▁
# wandb:   Validation_Accuracy ▇██▁▃
# wandb:       Validation_Loss █▄▂▁▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10024
# wandb:         Training_Loss 2.77859
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 2.77939
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced divine-sweep-69: https://wandb.ai/akashsainics21m003/cs6910_4/runs/p70fmpkj
# wandb: Find logs at: ./wandb/run-20220221_103125-p70fmpkj/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 6o906ajn with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run fancy-sweep-70
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_4
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_4/sweeps/kz23iyez
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_4/runs/6o906ajn
# wandb: Run data is saved locally in /content/wandb/run-20220221_103450-6o906ajn
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 7502... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▄▆▆▆▇████
# wandb:         Training_Loss █▅▄▃▃▂▂▂▁▁
# wandb:   Validation_Accuracy ▁▄▆▆▆▇████
# wandb:       Validation_Loss █▅▄▃▃▂▂▂▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.878
# wandb:         Training_Loss 0.3465
# wandb:   Validation_Accuracy 0.859
# wandb:       Validation_Loss 0.4122
# wandb:                epochs 10
# wandb:         test_accuracy 0.8523
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced fancy-sweep-70: https://wandb.ai/akashsainics21m003/cs6910_4/runs/6o906ajn
# wandb: Find logs at: ./wandb/run-20220221_103450-6o906ajn/logs/debug.log
# wandb:
