# %% [markdown]
# <a href="https://colab.research.google.com/github/returaj/cs6910/blob/assginment1_akash/ques4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.12.10-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 5.3 MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.5-py2.py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 46.1 MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.26-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 44.6 MB/s
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting yaspin>=1.0.0
#   Downloading yaspin-2.1.0-py3-none-any.whl (18 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.10.0.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: termcolor<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from yaspin>=1.0.0->wandb) (1.1.0)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=3cde115ab08a16d7cd9687210eab4278720793076e3dba9c403ca967b4fe03bc
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, yaspin, shortuuid, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.26 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.5 shortuuid-1.0.8 smmap-5.0.0 wandb-0.12.10 yaspin-2.1.0

# %%
import wandb
wandb.login()
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !ls "/content/drive/My Drive/DLASSIGNMENT"
# !python3 "/content/drive/My Drive/DLASSIGNMENT/runner.py"
# Out:
# activation_func.py  loss_func.py  optimizer.py	runner.py
# feed_forward_nn.py  measure.py	  __pycache__
# Create sweep with ID: awx1pj2s
# Sweep URL: https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: Agent Starting Run: mlmgws1h with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Currently logged in as: akashsainics21m003 (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run bright-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/mlmgws1h
# wandb: Run data is saved locally in /content/wandb/run-20220219_015755-mlmgws1h
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
#
# wandb: Waiting for W&B process to finish, PID 403... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▂▄▄▄▅▆▄██
# wandb:         TrainingLoss █▇▆▅▄▃▂▂▁▁
# wandb:   ValidationAccuracy ▁▂▄▃▄▅▅▄▇█
# wandb:       ValidationLoss █▇▅▅▃▃▂▂▁▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.61061
# wandb:         TrainingLoss 1.20077
# wandb:   ValidationAccuracy 0.59533
# wandb:       ValidationLoss 1.25109
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced bright-sweep-1: https://wandb.ai/akashsainics21m003/cs6910_1/runs/mlmgws1h
# wandb: Find logs at: ./wandb/run-20220219_015755-mlmgws1h/logs/debug.log
# wandb:
# wandb: Agent Starting Run: o00yjwfv with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run upbeat-sweep-2
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/o00yjwfv
# wandb: Run data is saved locally in /content/wandb/run-20220219_020133-o00yjwfv
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 475... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▁▁▁▁
# wandb:         TrainingLoss █▆▄▂▁
# wandb:   ValidationAccuracy ▁▁▁▁▁
# wandb:       ValidationLoss █▆▄▂▁
# wandb:                 step ▁▃▅▆█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.09996
# wandb:         TrainingLoss 2.30287
# wandb:   ValidationAccuracy 0.10033
# wandb:       ValidationLoss 2.30291
# wandb:                 step 5
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced upbeat-sweep-2: https://wandb.ai/akashsainics21m003/cs6910_1/runs/o00yjwfv
# wandb: Find logs at: ./wandb/run-20220219_020133-o00yjwfv/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 12g9ptn5 with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run olive-sweep-3
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/12g9ptn5
# wandb: Run data is saved locally in /content/wandb/run-20220219_020209-12g9ptn5
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 515... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▂▆▇█
# wandb:         TrainingLoss █▇▄▂▁
# wandb:   ValidationAccuracy ▁▂▅▇█
# wandb:       ValidationLoss █▇▄▂▁
# wandb:                 step ▁▃▅▆█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.34183
# wandb:         TrainingLoss 1.66115
# wandb:   ValidationAccuracy 0.3365
# wandb:       ValidationLoss 1.66607
# wandb:                 step 5
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced olive-sweep-3: https://wandb.ai/akashsainics21m003/cs6910_1/runs/12g9ptn5
# wandb: Find logs at: ./wandb/run-20220219_020209-12g9ptn5/logs/debug.log
# wandb:
# wandb: Agent Starting Run: oeo17sms with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run revived-sweep-4
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/oeo17sms
# wandb: Run data is saved locally in /content/wandb/run-20220219_020255-oeo17sms
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 551... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▆██▆▃▁█▁▆█
# wandb:         TrainingLoss ▁▁█▅▁▂▂▄▃▃
# wandb:   ValidationAccuracy ▃▁▁▃▆█▁█▃▁
# wandb:       ValidationLoss ▂▄▆█▁▁▄▄▅▇
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.1005
# wandb:         TrainingLoss 2.30264
# wandb:   ValidationAccuracy 0.0955
# wandb:       ValidationLoss 2.30297
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced revived-sweep-4: https://wandb.ai/akashsainics21m003/cs6910_1/runs/oeo17sms
# wandb: Find logs at: ./wandb/run-20220219_020255-oeo17sms/logs/debug.log
# wandb:
# wandb: Agent Starting Run: xse99njf with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run wobbly-sweep-5
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/xse99njf
# wandb: Run data is saved locally in /content/wandb/run-20220219_020914-xse99njf
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 611... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▅▆▇██████
# wandb:         TrainingLoss █▄▄▂▂▁▁▁▁▁
# wandb:   ValidationAccuracy ▁▅▆▇██████
# wandb:       ValidationLoss █▄▄▂▂▁▁▁▁▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.87352
# wandb:         TrainingLoss 0.47945
# wandb:   ValidationAccuracy 0.84467
# wandb:       ValidationLoss 0.53704
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced wobbly-sweep-5: https://wandb.ai/akashsainics21m003/cs6910_1/runs/xse99njf
# wandb: Find logs at: ./wandb/run-20220219_020914-xse99njf/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: we76ximg with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run rural-sweep-6
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/we76ximg
# wandb: Run data is saved locally in /content/wandb/run-20220219_021116-we76ximg
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 653... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▆▁▃▂██▆███
# wandb:         TrainingLoss ▁▅▃▄▂▂▂█▄▅
# wandb:   ValidationAccuracy ▃█▆▇▁▁▃▁▁▁
# wandb:       ValidationLoss ▅▁▇▂▆▄▅█▇▅
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.1005
# wandb:         TrainingLoss 2.30277
# wandb:   ValidationAccuracy 0.0955
# wandb:       ValidationLoss 2.30291
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced rural-sweep-6: https://wandb.ai/akashsainics21m003/cs6910_1/runs/we76ximg
# wandb: Find logs at: ./wandb/run-20220219_021116-we76ximg/logs/debug.log
# wandb:
# wandb: Agent Starting Run: n8i6h8md with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.5
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run peachy-sweep-7
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/n8i6h8md
# wandb: Run data is saved locally in /content/wandb/run-20220219_021202-n8i6h8md
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 689... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy █▁▆▆▂
# wandb:         TrainingLoss █▁▁▁▁
# wandb:   ValidationAccuracy ▁█▃▃▇
# wandb:       ValidationLoss █▁▁▁▁
# wandb:                 step ▁▃▅▆█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.0998
# wandb:         TrainingLoss 2.30311
# wandb:   ValidationAccuracy 0.10183
# wandb:       ValidationLoss 2.30335
# wandb:                 step 5
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced peachy-sweep-7: https://wandb.ai/akashsainics21m003/cs6910_1/runs/n8i6h8md
# wandb: Find logs at: ./wandb/run-20220219_021202-n8i6h8md/logs/debug.log
# wandb:
# wandb: Agent Starting Run: oq8tzi5e with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run dainty-sweep-8
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/oq8tzi5e
# wandb: Run data is saved locally in /content/wandb/run-20220219_021233-oq8tzi5e
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 723... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▂▄▅▅▅▇███
# wandb:         TrainingLoss █▆▅▄▃▂▂▁▁▁
# wandb:   ValidationAccuracy ▁▂▄▅▅▅▇██▇
# wandb:       ValidationLoss █▆▅▄▃▂▂▁▁▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.7212
# wandb:         TrainingLoss 0.87402
# wandb:   ValidationAccuracy 0.70833
# wandb:       ValidationLoss 0.93191
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced dainty-sweep-8: https://wandb.ai/akashsainics21m003/cs6910_1/runs/oq8tzi5e
# wandb: Find logs at: ./wandb/run-20220219_021233-oq8tzi5e/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 66wp518u with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run solar-sweep-9
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/66wp518u
# wandb: Run data is saved locally in /content/wandb/run-20220219_021333-66wp518u
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 759... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▁▆▁▆▂███▁
# wandb:         TrainingLoss █▂▁▃▄▃▃▃▅▄
# wandb:   ValidationAccuracy ██▃█▃▇▁▁▁█
# wandb:       ValidationLoss ▃▁▂▄█▃█▇█▂
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.0997
# wandb:         TrainingLoss 2.30264
# wandb:   ValidationAccuracy 0.10267
# wandb:       ValidationLoss 2.30266
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced solar-sweep-9: https://wandb.ai/akashsainics21m003/cs6910_1/runs/66wp518u
# wandb: Find logs at: ./wandb/run-20220219_021333-66wp518u/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 3rk7oskz with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run fresh-sweep-10
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/3rk7oskz
# wandb: Run data is saved locally in /content/wandb/run-20220219_021449-3rk7oskz
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 795... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▁▂▄▅▆▇▇██
# wandb:         TrainingLoss ██▅▄▃▃▃▂▁▁
# wandb:   ValidationAccuracy ▁▁▂▄▆▆▇▇██
# wandb:       ValidationLoss ██▅▄▃▃▃▂▁▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.80944
# wandb:         TrainingLoss 0.92406
# wandb:   ValidationAccuracy 0.79167
# wandb:       ValidationLoss 0.94536
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced fresh-sweep-10: https://wandb.ai/akashsainics21m003/cs6910_1/runs/3rk7oskz
# wandb: Find logs at: ./wandb/run-20220219_021449-3rk7oskz/logs/debug.log
# wandb:
# wandb: Agent Starting Run: sgweh2wy with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run misunderstood-sweep-11
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/sgweh2wy
# wandb: Run data is saved locally in /content/wandb/run-20220219_021550-sgweh2wy
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 831... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▆██▇▁█▃█▇█
# wandb:         TrainingLoss ▇▁█▃▆▄▁█▆▂
# wandb:   ValidationAccuracy ▃▁▁▂█▁▆▁▂▁
# wandb:       ValidationLoss ▆▂█▅▁▆▂▅▇▄
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.1005
# wandb:         TrainingLoss 2.30272
# wandb:   ValidationAccuracy 0.0955
# wandb:       ValidationLoss 2.303
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced misunderstood-sweep-11: https://wandb.ai/akashsainics21m003/cs6910_1/runs/sgweh2wy
# wandb: Find logs at: ./wandb/run-20220219_021550-sgweh2wy/logs/debug.log
# wandb:
# wandb: Agent Starting Run: t6waa1s1 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run sparkling-sweep-12
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/t6waa1s1
# wandb: Run data is saved locally in /content/wandb/run-20220219_021702-t6waa1s1
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 867... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▃███▁▂█▃▆▇
# wandb:         TrainingLoss █▇▆▆▅▄▃▃▂▁
# wandb:   ValidationAccuracy ▆▁▁▁█▇▁▆▃▂
# wandb:       ValidationLoss █▇▆▆▅▄▃▃▂▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.10031
# wandb:         TrainingLoss 26.48556
# wandb:   ValidationAccuracy 0.09717
# wandb:       ValidationLoss 26.48522
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced sparkling-sweep-12: https://wandb.ai/akashsainics21m003/cs6910_1/runs/t6waa1s1
# wandb: Find logs at: ./wandb/run-20220219_021702-t6waa1s1/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 4x9yrilt with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run denim-sweep-13
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/4x9yrilt
# wandb: Run data is saved locally in /content/wandb/run-20220219_021924-4x9yrilt
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 907... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▆▁▃██
# wandb:         TrainingLoss ▃█▂▁▃
# wandb:   ValidationAccuracy ▃█▆▁▁
# wandb:       ValidationLoss ▁▄▃▃█
# wandb:                 step ▁▃▅▆█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.1005
# wandb:         TrainingLoss 2.30346
# wandb:   ValidationAccuracy 0.0955
# wandb:       ValidationLoss 2.3043
# wandb:                 step 5
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced denim-sweep-13: https://wandb.ai/akashsainics21m003/cs6910_1/runs/4x9yrilt
# wandb: Find logs at: ./wandb/run-20220219_021924-4x9yrilt/logs/debug.log
# wandb:
# wandb: Agent Starting Run: sh1sds4b with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run splendid-sweep-14
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/sh1sds4b
# wandb: Run data is saved locally in /content/wandb/run-20220219_022035-sh1sds4b
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 943... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▃▄▇▇▇████
# wandb:         TrainingLoss █▇▅▃▂▂▁▁▁▁
# wandb:   ValidationAccuracy ▁▃▄▇▇▇████
# wandb:       ValidationLoss █▇▅▂▂▂▁▁▁▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.89159
# wandb:         TrainingLoss 0.30016
# wandb:   ValidationAccuracy 0.86783
# wandb:       ValidationLoss 0.36962
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced splendid-sweep-14: https://wandb.ai/akashsainics21m003/cs6910_1/runs/sh1sds4b
# wandb: Find logs at: ./wandb/run-20220219_022035-sh1sds4b/logs/debug.log
# wandb:
# wandb: Agent Starting Run: bo5xkt9e with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run astral-sweep-15
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/bo5xkt9e
# wandb: Run data is saved locally in /content/wandb/run-20220219_022327-bo5xkt9e
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 983... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▂▄▆▇▇████
# wandb:         TrainingLoss █▇▅▃▂▂▁▁▁▁
# wandb:   ValidationAccuracy ▁▂▄▆▇▇████
# wandb:       ValidationLoss █▇▅▃▂▂▁▁▁▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.8793
# wandb:         TrainingLoss 0.34177
# wandb:   ValidationAccuracy 0.85767
# wandb:       ValidationLoss 0.39112
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced astral-sweep-15: https://wandb.ai/akashsainics21m003/cs6910_1/runs/bo5xkt9e
# wandb: Find logs at: ./wandb/run-20220219_022327-bo5xkt9e/logs/debug.log
# wandb:
# wandb: Agent Starting Run: yimib8q8 with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run solar-sweep-16
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/yimib8q8
# wandb: Run data is saved locally in /content/wandb/run-20220219_022518-yimib8q8
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1021... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▂▄▄▅▇▇███
# wandb:         TrainingLoss █▆▅▄▄▃▂▂▁▁
# wandb:   ValidationAccuracy ▁▂▄▄▅▇▇███
# wandb:       ValidationLoss █▆▅▄▄▃▂▁▁▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.87257
# wandb:         TrainingLoss 0.43868
# wandb:   ValidationAccuracy 0.85833
# wandb:       ValidationLoss 0.49155
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced solar-sweep-16: https://wandb.ai/akashsainics21m003/cs6910_1/runs/yimib8q8
# wandb: Find logs at: ./wandb/run-20220219_022518-yimib8q8/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 78n1bpw5 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run tough-sweep-17
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/78n1bpw5
# wandb: Run data is saved locally in /content/wandb/run-20220219_022735-78n1bpw5
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1061... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▃▅▇▇▇████
# wandb:         TrainingLoss █▇▄▃▂▂▂▁▁▁
# wandb:   ValidationAccuracy ▁▃▅▇▇▇████
# wandb:       ValidationLoss █▇▄▂▂▂▂▁▁▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.85596
# wandb:         TrainingLoss 0.47197
# wandb:   ValidationAccuracy 0.84267
# wandb:       ValidationLoss 0.5097
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced tough-sweep-17: https://wandb.ai/akashsainics21m003/cs6910_1/runs/78n1bpw5
# wandb: Find logs at: ./wandb/run-20220219_022735-78n1bpw5/logs/debug.log
# wandb:
# wandb: Agent Starting Run: ldl25k56 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run denim-sweep-18
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/ldl25k56
# wandb: Run data is saved locally in /content/wandb/run-20220219_023123-ldl25k56
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1103... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▅▅▇▇▇▇█▇█
# wandb:         TrainingLoss █▄▃▂▂▂▂▁▁▁
# wandb:   ValidationAccuracy ▁▅▆▇▇▇████
# wandb:       ValidationLoss █▄▃▂▂▂▂▁▁▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.90037
# wandb:         TrainingLoss 0.27727
# wandb:   ValidationAccuracy 0.87483
# wandb:       ValidationLoss 0.35537
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced denim-sweep-18: https://wandb.ai/akashsainics21m003/cs6910_1/runs/ldl25k56
# wandb: Find logs at: ./wandb/run-20220219_023123-ldl25k56/logs/debug.log
# wandb:
# wandb: Agent Starting Run: y3lg6vc6 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run glad-sweep-19
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/y3lg6vc6
# wandb: Run data is saved locally in /content/wandb/run-20220219_023239-y3lg6vc6
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1139... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▅▅▇▇█████
# wandb:         TrainingLoss █▅▄▃▂▂▂▁▁▁
# wandb:   ValidationAccuracy ▁▅▅▇██████
# wandb:       ValidationLoss █▅▄▃▂▂▂▁▁▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.88894
# wandb:         TrainingLoss 0.42988
# wandb:   ValidationAccuracy 0.86567
# wandb:       ValidationLoss 0.48732
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced glad-sweep-19: https://wandb.ai/akashsainics21m003/cs6910_1/runs/y3lg6vc6
# wandb: Find logs at: ./wandb/run-20220219_023239-y3lg6vc6/logs/debug.log
# wandb:
# wandb: Agent Starting Run: u26cupsy with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run dashing-sweep-20
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/u26cupsy
# wandb: Run data is saved locally in /content/wandb/run-20220219_023330-u26cupsy
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1175... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▂▄▅▅▆▆▇██
# wandb:         TrainingLoss █▇▅▄▃▃▂▂▁▁
# wandb:   ValidationAccuracy ▁▂▄▅▅▆▆▇██
# wandb:       ValidationLoss █▇▅▅▃▃▂▂▁▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.80261
# wandb:         TrainingLoss 0.60694
# wandb:   ValidationAccuracy 0.7925
# wandb:       ValidationLoss 0.62679
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced dashing-sweep-20: https://wandb.ai/akashsainics21m003/cs6910_1/runs/u26cupsy
# wandb: Find logs at: ./wandb/run-20220219_023330-u26cupsy/logs/debug.log
# wandb:
# wandb: Agent Starting Run: ymt9wbjy with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run rural-sweep-21
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/ymt9wbjy
# wandb: Run data is saved locally in /content/wandb/run-20220219_023431-ymt9wbjy
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1211... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▁▂▃▅▆▇████
# wandb:         TrainingLoss ██▆▄▃▂▂▁▁▁
# wandb:   ValidationAccuracy ▁▂▃▅▆▇████
# wandb:       ValidationLoss ██▆▄▃▂▂▁▁▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.79337
# wandb:         TrainingLoss 0.57408
# wandb:   ValidationAccuracy 0.79033
# wandb:       ValidationLoss 0.59269
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced rural-sweep-21: https://wandb.ai/akashsainics21m003/cs6910_1/runs/ymt9wbjy
# wandb: Find logs at: ./wandb/run-20220219_023431-ymt9wbjy/logs/debug.log
# wandb:
# wandb: Agent Starting Run: iv34uclf with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run crimson-sweep-22
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/iv34uclf
# wandb: Run data is saved locally in /content/wandb/run-20220219_023633-iv34uclf
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1250... (success).
# wandb:
# wandb: Run history:
# wandb:     TrainingAccuracy ▃▃▁██████▃
# wandb:         TrainingLoss ██▆▅▃▄▁▂▂▁
# wandb:   ValidationAccuracy ▆▆█▁▁▁▁▁▁▆
# wandb:       ValidationLoss █▇▅▂▃▄▃▅▂▁
# wandb:                 step ▁▂▃▃▄▅▆▆▇█
# wandb:
# wandb: Run summary:
# wandb:     TrainingAccuracy 0.09996
# wandb:         TrainingLoss 2.30285
# wandb:   ValidationAccuracy 0.10033
# wandb:       ValidationLoss 2.30294
# wandb:                 step 10
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced crimson-sweep-22: https://wandb.ai/akashsainics21m003/cs6910_1/runs/iv34uclf
# wandb: Find logs at: ./wandb/run-20220219_023633-iv34uclf/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 9u3bt1yo with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run eager-sweep-23
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/cs6910_1
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/cs6910_1/sweeps/awx1pj2s
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/cs6910_1/runs/9u3bt1yo
# wandb: Run data is saved locally in /content/wandb/run-20220219_023723-9u3bt1yo
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
