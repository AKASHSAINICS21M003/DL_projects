# %% [markdown]
# <a href="https://colab.research.google.com/github/returaj/cs6910/blob/assginment1_akash/ques4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading wandb-0.12.10-py2.py3-none-any.whl (1.7 MB)
#      |████████████████████████████████| 1.7 MB 15.4 MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.5-py2.py3-none-any.whl (144 kB)
#      |████████████████████████████████| 144 kB 55.8 MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting yaspin>=1.0.0
#   Downloading yaspin-2.1.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 53.2 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.8-py3-none-any.whl (9.5 kB)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.10.0.2)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: termcolor<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from yaspin>=1.0.0->wandb) (1.1.0)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=85a392048de7af25a0292c147f4494444992ca42e4e38fe29e0046a95f696a2b
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, yaspin, shortuuid, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.5 shortuuid-1.0.8 smmap-5.0.0 wandb-0.12.10 yaspin-2.1.0

# %%
import wandb
wandb.login()
# Out:
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit: ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !ls "/content/drive/My Drive/DLASSIGNMENT"
# !python3 "/content/drive/My Drive/DLASSIGNMENT/runner.py"
# Out:
# activation_func.py  loss_func.py  optimizer.py	runner.py
# feed_forward_nn.py  measure.py	  __pycache__
# Create sweep with ID: cxmwea0x
# Sweep URL: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: Agent Starting Run: xb3tlo88 with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Currently logged in as: akashsainics21m003 (use `wandb login --relogin` to force relogin)
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run helpful-sweep-1
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/xb3tlo88
# wandb: Run data is saved locally in /content/wandb/run-20220222_121620-xb3tlo88
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
#
# wandb: Waiting for W&B process to finish, PID 385... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▃▁▃▇█
# wandb:         Training_Loss █▆▄▃▁
# wandb:   Validation_Accuracy ▆█▇▂▁
# wandb:       Validation_Loss █▆▄▃▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10031
# wandb:         Training_Loss 11.35544
# wandb:   Validation_Accuracy 0.09717
# wandb:       Validation_Loss 11.35592
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced helpful-sweep-1: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/xb3tlo88
# wandb: Find logs at: ./wandb/run-20220222_121620-xb3tlo88/logs/debug.log
# wandb:
# wandb: Agent Starting Run: fkwcpg2a with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run faithful-sweep-2
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/fkwcpg2a
# wandb: Run data is saved locally in /content/wandb/run-20220222_121657-fkwcpg2a
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 425... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▂▇▆█
# wandb:         Training_Loss █▆▂▃▁
# wandb:   Validation_Accuracy ▁▂▆▆█
# wandb:       Validation_Loss █▇▁▄▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.87602
# wandb:         Training_Loss 0.48611
# wandb:   Validation_Accuracy 0.8625
# wandb:       Validation_Loss 0.52935
# wandb:                epochs 5
# wandb:         test_accuracy 0.8556
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced faithful-sweep-2: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/fkwcpg2a
# wandb: Find logs at: ./wandb/run-20220222_121657-fkwcpg2a/logs/debug.log
# wandb:
# wandb: Agent Starting Run: ace6oyy1 with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run whole-sweep-3
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/ace6oyy1
# wandb: Run data is saved locally in /content/wandb/run-20220222_121830-ace6oyy1
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 475... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▂▂▃▃█▁██▁▃
# wandb:         Training_Loss ▄▄▄▄▄▁▄▃▅█
# wandb:   Validation_Accuracy ▇▇▆▆▁█▁▁█▆
# wandb:       Validation_Loss ▃▄▃▃▆▁▆▄▄█
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09996
# wandb:         Training_Loss 2.31473
# wandb:   Validation_Accuracy 0.10033
# wandb:       Validation_Loss 2.31494
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced whole-sweep-3: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/ace6oyy1
# wandb: Find logs at: ./wandb/run-20220222_121830-ace6oyy1/logs/debug.log
# wandb:
# wandb: Agent Starting Run: nn6ap5zy with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run resilient-sweep-4
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/nn6ap5zy
# wandb: Run data is saved locally in /content/wandb/run-20220222_122024-nn6ap5zy
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 533... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁█▇▁▄▁▁▄
# wandb:         Training_Loss █▇▆▆▅▄▃▃▂▁
# wandb:   Validation_Accuracy ███▁▂█▅██▅
# wandb:       Validation_Loss █▇▆▆▅▄▃▃▂▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09996
# wandb:         Training_Loss 6.74276
# wandb:   Validation_Accuracy 0.10033
# wandb:       Validation_Loss 6.74256
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced resilient-sweep-4: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/nn6ap5zy
# wandb: Find logs at: ./wandb/run-20220222_122024-nn6ap5zy/logs/debug.log
# wandb:
# wandb: Agent Starting Run: a1z3u3uh with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run major-sweep-5
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/a1z3u3uh
# wandb: Run data is saved locally in /content/wandb/run-20220222_122111-a1z3u3uh
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 579... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁
# wandb:         Training_Loss █▄▂▂▁
# wandb:   Validation_Accuracy ▁▁▁▁▁
# wandb:       Validation_Loss ▁▃▆▇█
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30258
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30268
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced major-sweep-5: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/a1z3u3uh
# wandb: Find logs at: ./wandb/run-20220222_122111-a1z3u3uh/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: s4c751jc with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run decent-sweep-6
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/s4c751jc
# wandb: Run data is saved locally in /content/wandb/run-20220222_122325-s4c751jc
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 643... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁▁████
# wandb:         Training_Loss █▅▃▂▂▁▁▁▁▁
# wandb:   Validation_Accuracy ██████▁▁▁▁
# wandb:       Validation_Loss █▅▃▂▂▁▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 12.79853
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 12.79911
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced decent-sweep-6: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/s4c751jc
# wandb: Find logs at: ./wandb/run-20220222_122325-s4c751jc/logs/debug.log
# wandb:
# wandb: Agent Starting Run: bo7qee9p with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run logical-sweep-7
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/bo7qee9p
# wandb: Run data is saved locally in /content/wandb/run-20220222_122408-bo7qee9p
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 687... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▂▃▄▅▆▇▇█
# wandb:         Training_Loss ███▄▃▃▂▂▁▁
# wandb:   Validation_Accuracy ▁▁▂▃▄▅▆▇▇█
# wandb:       Validation_Loss ███▄▃▃▂▂▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.40031
# wandb:         Training_Loss 1.39413
# wandb:   Validation_Accuracy 0.40517
# wandb:       Validation_Loss 1.39481
# wandb:                epochs 10
# wandb:         test_accuracy 0.3969
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced logical-sweep-7: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/bo7qee9p
# wandb: Find logs at: ./wandb/run-20220222_122408-bo7qee9p/logs/debug.log
# wandb:
# wandb: Agent Starting Run: ndn5wqzy with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run flowing-sweep-8
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/ndn5wqzy
# wandb: Run data is saved locally in /content/wandb/run-20220222_122450-ndn5wqzy
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 729... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▂▃▅▆▆▇▇██
# wandb:         Training_Loss █▇▅▄▃▂▂▂▁▁
# wandb:   Validation_Accuracy ▁▂▃▅▆▆▇▇██
# wandb:       Validation_Loss █▇▅▄▃▂▂▂▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.83054
# wandb:         Training_Loss 0.48301
# wandb:   Validation_Accuracy 0.81517
# wandb:       Validation_Loss 0.54056
# wandb:                epochs 10
# wandb:         test_accuracy 0.812
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced flowing-sweep-8: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/ndn5wqzy
# wandb: Find logs at: ./wandb/run-20220222_122450-ndn5wqzy/logs/debug.log
# wandb:
# wandb: Agent Starting Run: j0pfbmqm with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run classic-sweep-9
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/j0pfbmqm
# wandb: Run data is saved locally in /content/wandb/run-20220222_122854-j0pfbmqm
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 819... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ███▃▃▁▃███
# wandb:         Training_Loss █▄▂▂▁▁▁▁▁▁
# wandb:   Validation_Accuracy ▁▁▁▆▆█▆▁▁▁
# wandb:       Validation_Loss █▄▂▂▁▁▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.3028
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30289
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced classic-sweep-9: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/j0pfbmqm
# wandb: Find logs at: ./wandb/run-20220222_122854-j0pfbmqm/logs/debug.log
# wandb:
# wandb: Agent Starting Run: ore5m7k6 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run clean-sweep-10
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/ore5m7k6
# wandb: Run data is saved locally in /content/wandb/run-20220222_122941-ore5m7k6
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 863... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▄█▂▁▁▂▂▇█▆
# wandb:         Training_Loss █▆▄▃▂▂▁▁▁▁
# wandb:   Validation_Accuracy ▅▁▇██▇▇▂▁▃
# wandb:       Validation_Loss █▆▄▃▂▂▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10024
# wandb:         Training_Loss 2.49386
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 2.49437
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced clean-sweep-10: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/ore5m7k6
# wandb: Find logs at: ./wandb/run-20220222_122941-ore5m7k6/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 3dr0fah4 with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run honest-sweep-11
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/3dr0fah4
# wandb: Run data is saved locally in /content/wandb/run-20220222_123125-3dr0fah4
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 921... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▃▄▅▆▆▇██
# wandb:         Training_Loss ██▅▅▄▃▃▂▁▁
# wandb:   Validation_Accuracy ▁▁▃▄▅▆▆▇██
# wandb:       Validation_Loss ██▅▅▄▃▃▂▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.79181
# wandb:         Training_Loss 0.89405
# wandb:   Validation_Accuracy 0.7865
# wandb:       Validation_Loss 0.91078
# wandb:                epochs 10
# wandb:         test_accuracy 0.785
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced honest-sweep-11: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/3dr0fah4
# wandb: Find logs at: ./wandb/run-20220222_123125-3dr0fah4/logs/debug.log
# wandb:
# wandb: Agent Starting Run: te9hwdgn with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0.5
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run rose-sweep-12
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/te9hwdgn
# wandb: Run data is saved locally in /content/wandb/run-20220222_123334-te9hwdgn
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 976... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁
# wandb:         Training_Loss █▆▄▂▁
# wandb:   Validation_Accuracy ▁▁▁▁▁
# wandb:       Validation_Loss █▆▄▂▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 1862156058.38747
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 1862156058.38748
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced rose-sweep-12: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/te9hwdgn
# wandb: Find logs at: ./wandb/run-20220222_123334-te9hwdgn/logs/debug.log
# wandb:
# wandb: Agent Starting Run: hplzmb0q with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run desert-sweep-13
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/hplzmb0q
# wandb: Run data is saved locally in /content/wandb/run-20220222_123406-hplzmb0q
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1012... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▃███▁
# wandb:         Training_Loss █▁▂▂▃
# wandb:   Validation_Accuracy ▆▁▁▁█
# wandb:       Validation_Loss ▁▅▆█▆
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10024
# wandb:         Training_Loss 2.30258
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 2.30268
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced desert-sweep-13: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/hplzmb0q
# wandb: Find logs at: ./wandb/run-20220222_123406-hplzmb0q/logs/debug.log
# wandb:
# wandb: Agent Starting Run: dip75q8b with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run stellar-sweep-14
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/dip75q8b
# wandb: Run data is saved locally in /content/wandb/run-20220222_123427-dip75q8b
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1046... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▇▁█▁▇▄▆█▁▂
# wandb:         Training_Loss █▇▆▆▅▄▃▂▂▁
# wandb:   Validation_Accuracy ▂█▁█▂▅▃▁█▇
# wandb:       Validation_Loss █▇▆▆▅▄▃▂▂▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09974
# wandb:         Training_Loss 11.20943
# wandb:   Validation_Accuracy 0.10233
# wandb:       Validation_Loss 11.20897
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced stellar-sweep-14: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/dip75q8b
# wandb: Find logs at: ./wandb/run-20220222_123427-dip75q8b/logs/debug.log
# wandb:
# wandb: Agent Starting Run: ak97947w with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run pretty-sweep-15
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/ak97947w
# wandb: Run data is saved locally in /content/wandb/run-20220222_123524-ak97947w
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1082... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▅█▁▁▁
# wandb:         Training_Loss █▄▂▁▁
# wandb:   Validation_Accuracy ▇█▁▁▁
# wandb:       Validation_Loss █▄▂▁▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.31261
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.31265
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced pretty-sweep-15: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/ak97947w
# wandb: Find logs at: ./wandb/run-20220222_123524-ak97947w/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 7j1sjdsa with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run faithful-sweep-16
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/7j1sjdsa
# wandb: Run data is saved locally in /content/wandb/run-20220222_123550-7j1sjdsa
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1118... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▄▇▇▇█████
# wandb:         Training_Loss █▅▃▂▂▂▁▁▁▁
# wandb:   Validation_Accuracy ▁▅▇▇▇██▇▇█
# wandb:       Validation_Loss █▅▂▂▂▂▁▁▂▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.89472
# wandb:         Training_Loss 0.28107
# wandb:   Validation_Accuracy 0.869
# wandb:       Validation_Loss 0.35707
# wandb:                epochs 10
# wandb:         test_accuracy 0.8633
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced faithful-sweep-16: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/7j1sjdsa
# wandb: Find logs at: ./wandb/run-20220222_123550-7j1sjdsa/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: v1jn8kns with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run fragrant-sweep-17
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/v1jn8kns
# wandb: Run data is saved locally in /content/wandb/run-20220222_123739-v1jn8kns
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1156... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁▁▁▁▁▁
# wandb:         Training_Loss █▇▅▅▄▃▂▁▁▁
# wandb:   Validation_Accuracy ▁▁▁▁▁▁▁▁▁▁
# wandb:       Validation_Loss ▁▂▃▄▅▆▆▇▇█
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30258
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30265
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced fragrant-sweep-17: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/v1jn8kns
# wandb: Find logs at: ./wandb/run-20220222_123739-v1jn8kns/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 5j60p9k2 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run pious-sweep-18
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/5j60p9k2
# wandb: Run data is saved locally in /content/wandb/run-20220222_123847-5j60p9k2
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1192... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▂▄▄▅▆▇▇█
# wandb:         Training_Loss ██▇▅▄▄▃▂▂▁
# wandb:   Validation_Accuracy ▁▁▂▄▄▆▆▇▇█
# wandb:       Validation_Loss ██▇▅▄▄▃▂▂▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.73343
# wandb:         Training_Loss 0.81402
# wandb:   Validation_Accuracy 0.7305
# wandb:       Validation_Loss 0.83218
# wandb:                epochs 10
# wandb:         test_accuracy 0.7279
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced pious-sweep-18: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/5j60p9k2
# wandb: Find logs at: ./wandb/run-20220222_123847-5j60p9k2/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 8bmku8xn with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run helpful-sweep-19
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/8bmku8xn
# wandb: Run data is saved locally in /content/wandb/run-20220222_123949-8bmku8xn
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1228... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▂█▁█
# wandb:         Training_Loss █▆▄▃▁
# wandb:   Validation_Accuracy █▇▁█▁
# wandb:       Validation_Loss █▆▄▃▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10024
# wandb:         Training_Loss 13.27575
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 13.27555
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced helpful-sweep-19: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/8bmku8xn
# wandb: Find logs at: ./wandb/run-20220222_123949-8bmku8xn/logs/debug.log
# wandb:
# wandb: Agent Starting Run: tmmt70l2 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run swept-sweep-20
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/tmmt70l2
# wandb: Run data is saved locally in /content/wandb/run-20220222_124036-tmmt70l2
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1264... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▇█▁█▂██▂▂▆
# wandb:         Training_Loss ▁▃▅▅▁▆▅█▃▁
# wandb:   Validation_Accuracy ▂▁█▁▇▁▁▇▇▃
# wandb:       Validation_Loss ▂▅▃█▁█▅█▄▂
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10024
# wandb:         Training_Loss 2.30515
# wandb:   Validation_Accuracy 0.09783
# wandb:       Validation_Loss 2.30503
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced swept-sweep-20: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/tmmt70l2
# wandb: Find logs at: ./wandb/run-20220222_124036-tmmt70l2/logs/debug.log
# wandb:
# wandb: Agent Starting Run: qnep33rj with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run flowing-sweep-21
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/qnep33rj
# wandb: Run data is saved locally in /content/wandb/run-20220222_124134-qnep33rj
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1300... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▅▅█▅▁
# wandb:         Training_Loss ▁█▄▄▁
# wandb:   Validation_Accuracy ▄▄▁▄█
# wandb:       Validation_Loss ▆▅▇█▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09996
# wandb:         Training_Loss 2.30262
# wandb:   Validation_Accuracy 0.10033
# wandb:       Validation_Loss 2.30255
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced flowing-sweep-21: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/qnep33rj
# wandb: Find logs at: ./wandb/run-20220222_124134-qnep33rj/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 6ztv2orq with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run daily-sweep-22
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/6ztv2orq
# wandb: Run data is saved locally in /content/wandb/run-20220222_124210-6ztv2orq
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1334... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▅▃██▁
# wandb:         Training_Loss ▂▇▁█▅
# wandb:   Validation_Accuracy ▄▆▁▁█
# wandb:       Validation_Loss ▁▂▅█▄
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.0998
# wandb:         Training_Loss 2.30294
# wandb:   Validation_Accuracy 0.10183
# wandb:       Validation_Loss 2.30319
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced daily-sweep-22: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/6ztv2orq
# wandb: Find logs at: ./wandb/run-20220222_124210-6ztv2orq/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 8z1nuwfw with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run copper-sweep-23
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/8z1nuwfw
# wandb: Run data is saved locally in /content/wandb/run-20220222_124247-8z1nuwfw
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1370... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁█▃▂▂▂▂▂▂▃
# wandb:         Training_Loss █▃▂▂▂▂▁▁▁▁
# wandb:   Validation_Accuracy ▁█▃▂▃▂▂▁▂▂
# wandb:       Validation_Loss █▃▂▂▂▂▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.11019
# wandb:         Training_Loss 3.12951
# wandb:   Validation_Accuracy 0.103
# wandb:       Validation_Loss 3.14034
# wandb:                epochs 10
# wandb:         test_accuracy 0.109
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced copper-sweep-23: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/8z1nuwfw
# wandb: Find logs at: ./wandb/run-20220222_124247-8z1nuwfw/logs/debug.log
# wandb:
# wandb: Agent Starting Run: ivak6eq8 with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run sunny-sweep-24
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/ivak6eq8
# wandb: Run data is saved locally in /content/wandb/run-20220222_124512-ivak6eq8
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1410... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▄▆█
# wandb:         Training_Loss █▇▆▃▁
# wandb:   Validation_Accuracy ▁▁▄▆█
# wandb:       Validation_Loss █▇▆▃▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.24552
# wandb:         Training_Loss 1.91178
# wandb:   Validation_Accuracy 0.24533
# wandb:       Validation_Loss 1.91178
# wandb:                epochs 5
# wandb:         test_accuracy 0.2471
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced sunny-sweep-24: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/ivak6eq8
# wandb: Find logs at: ./wandb/run-20220222_124512-ivak6eq8/logs/debug.log
# wandb:
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: yj4xb8yu with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run drawn-sweep-25
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/yj4xb8yu
# wandb: Run data is saved locally in /content/wandb/run-20220222_124625-yj4xb8yu
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1448... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▅▅█▁▃
# wandb:         Training_Loss █▁█▃▅
# wandb:   Validation_Accuracy ▄▄▁█▆
# wandb:       Validation_Loss ▄▁█▁▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09996
# wandb:         Training_Loss 2.30518
# wandb:   Validation_Accuracy 0.10033
# wandb:       Validation_Loss 2.30494
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced drawn-sweep-25: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/yj4xb8yu
# wandb: Find logs at: ./wandb/run-20220222_124625-yj4xb8yu/logs/debug.log
# wandb:
# wandb: Agent Starting Run: b1kihmff with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run glowing-sweep-26
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/b1kihmff
# wandb: Run data is saved locally in /content/wandb/run-20220222_124657-b1kihmff
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1482... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ██▆█▁███▅▆
# wandb:         Training_Loss ▅█▆▂▁▅▁▅▄▇
# wandb:   Validation_Accuracy ▁▁▃▁█▁▁▁▄▃
# wandb:       Validation_Loss ▅█▅▃▁▅▄▄▃▇
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.10031
# wandb:         Training_Loss 2.30259
# wandb:   Validation_Accuracy 0.09717
# wandb:       Validation_Loss 2.30278
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced glowing-sweep-26: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/b1kihmff
# wandb: Find logs at: ./wandb/run-20220222_124657-b1kihmff/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 9vi22a83 with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nesterov_gd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run different-sweep-27
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/9vi22a83
# wandb: Run data is saved locally in /content/wandb/run-20220222_124733-9vi22a83
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 1518... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▂▂▄▆▆▇▇██
# wandb:         Training_Loss █▇▆▄▄▃▂▂▂▁
# wandb:   Validation_Accuracy ▁▂▂▄▆▆▇▇██
# wandb:       Validation_Loss █▇▆▄▄▃▂▂▂▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.84796
# wandb:         Training_Loss 0.50119
# wandb:   Validation_Accuracy 0.83133
# wandb:       Validation_Loss 0.54331
# wandb:                epochs 10
# wandb:         test_accuracy 0.83
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced different-sweep-27: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/9vi22a83
# wandb: Find logs at: ./wandb/run-20220222_124733-9vi22a83/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 26b4yb72 with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0
# wandb: 	weight_init: random
# ...
# wandb:         Training_Loss █▃▁▁▁▁▁▁▁▁
# wandb:   Validation_Accuracy ▆▇██▆▇▁▁▇▅
# wandb:       Validation_Loss █▃▁▁▁▁▁▁▁▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09996
# wandb:         Training_Loss 2.32031
# wandb:   Validation_Accuracy 0.10033
# wandb:       Validation_Loss 2.31981
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced atomic-sweep-61: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/59vb641x
# wandb: Find logs at: ./wandb/run-20220222_133311-59vb641x/logs/debug.log
# wandb:
# wandb: Agent Starting Run: bxkqit4c with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run mild-sweep-62
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/bxkqit4c
# wandb: Run data is saved locally in /content/wandb/run-20220222_133418-bxkqit4c
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2810... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▇▇▇▇▇▆▆▅▁
# wandb:         Training_Loss █▇▇▆▆▅▄▃▂▁
# wandb:   Validation_Accuracy ▁██████▇▇▅
# wandb:       Validation_Loss █▇▇▆▆▅▄▃▂▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.09674
# wandb:         Training_Loss 2.26815
# wandb:   Validation_Accuracy 0.09933
# wandb:       Validation_Loss 2.26709
# wandb:                epochs 10
# wandb:         test_accuracy 0.0987
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced mild-sweep-62: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/bxkqit4c
# wandb: Find logs at: ./wandb/run-20220222_133418-bxkqit4c/logs/debug.log
# wandb:
# wandb: Agent Starting Run: y4zejtrf with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run lilac-sweep-63
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/y4zejtrf
# wandb: Run data is saved locally in /content/wandb/run-20220222_133516-y4zejtrf
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2848... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁
# wandb:         Training_Loss █▅▂▁▁
# wandb:   Validation_Accuracy ▁▁▁▁▁
# wandb:       Validation_Loss ▁▃▆▇█
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30258
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30266
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced lilac-sweep-63: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/y4zejtrf
# wandb: Find logs at: ./wandb/run-20220222_133516-y4zejtrf/logs/debug.log
# wandb:
# wandb: Agent Starting Run: qrfkcuqr with config:
# wandb: 	act_func: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: adam
# wandb: 	reg: 0.0005
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run zany-sweep-64
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/qrfkcuqr
# wandb: Run data is saved locally in /content/wandb/run-20220222_133552-qrfkcuqr
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2884... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▁▃▁▃
# wandb:         Training_Loss █▇▂▆▁
# wandb:   Validation_Accuracy ▁█▆█▆
# wandb:       Validation_Loss █▁▅▆█
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.0998
# wandb:         Training_Loss 2.30317
# wandb:   Validation_Accuracy 0.10183
# wandb:       Validation_Loss 2.3035
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced zany-sweep-64: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/qrfkcuqr
# wandb: Find logs at: ./wandb/run-20220222_133552-qrfkcuqr/logs/debug.log
# wandb:
# wandb: Agent Starting Run: v0fidlac with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run eager-sweep-65
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/v0fidlac
# wandb: Run data is saved locally in /content/wandb/run-20220222_133706-v0fidlac
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2920... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy █▂█▁█
# wandb:         Training_Loss ▂▁█▂▆
# wandb:   Validation_Accuracy ▁▇▁█▁
# wandb:       Validation_Loss ▄▁█▂▅
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30351
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30377
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced eager-sweep-65: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/v0fidlac
# wandb: Find logs at: ./wandb/run-20220222_133706-v0fidlac/logs/debug.log
# wandb:
# wandb: Agent Starting Run: j3gfec7a with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 64
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run toasty-sweep-66
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/j3gfec7a
# wandb: Run data is saved locally in /content/wandb/run-20220222_133748-j3gfec7a
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2956... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁█
# wandb:         Training_Loss █▅▄▂▁
# wandb:   Validation_Accuracy ████▁
# wandb:       Validation_Loss ▁▄▅▇█
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30258
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30265
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced toasty-sweep-66: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/j3gfec7a
# wandb: Find logs at: ./wandb/run-20220222_133748-j3gfec7a/logs/debug.log
# wandb:
# wandb: Agent Starting Run: 30poclcw with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: rmsprop
# wandb: 	reg: 0
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run wild-sweep-67
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/30poclcw
# wandb: Run data is saved locally in /content/wandb/run-20220222_133825-30poclcw
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 2990... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▅▅██
# wandb:         Training_Loss █▄▄▂▁
# wandb:   Validation_Accuracy ▁▆▅██
# wandb:       Validation_Loss █▄▄▂▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.63693
# wandb:         Training_Loss 0.85224
# wandb:   Validation_Accuracy 0.63283
# wandb:       Validation_Loss 0.88735
# wandb:                epochs 5
# wandb:         test_accuracy 0.6282
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced wild-sweep-67: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/30poclcw
# wandb: Find logs at: ./wandb/run-20220222_133825-30poclcw/logs/debug.log
# wandb:
# wandb: Agent Starting Run: em8uq2bk with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 5
# wandb: 	hidden_nodes: 128
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: nadam
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run mild-sweep-68
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/em8uq2bk
# wandb: Run data is saved locally in /content/wandb/run-20220222_133851-em8uq2bk
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 3026... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁
# wandb:         Training_Loss █▇▃▂▁
# wandb:   Validation_Accuracy ▁▁▁▁▁
# wandb:       Validation_Loss ▁▃▅▇█
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 2.30258
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 2.30267
# wandb:                epochs 5
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced mild-sweep-68: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/em8uq2bk
# wandb: Find logs at: ./wandb/run-20220222_133851-em8uq2bk/logs/debug.log
# wandb:
# wandb: Agent Starting Run: v071m2r6 with config:
# wandb: 	act_func: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: 3
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: sgd
# wandb: 	reg: 0.5
# wandb: 	weight_init: xavier
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run summer-sweep-69
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/v071m2r6
# wandb: Run data is saved locally in /content/wandb/run-20220222_134101-v071m2r6
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 3068... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▃█
# wandb:         Training_Loss █▅▃▂▁
# wandb:   Validation_Accuracy ▂▂▁▃█
# wandb:       Validation_Loss █▅▃▂▁
# wandb:                epochs ▁▃▅▆█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.12026
# wandb:         Training_Loss 2.42735
# wandb:   Validation_Accuracy 0.11817
# wandb:       Validation_Loss 2.42736
# wandb:                epochs 5
# wandb:         test_accuracy 0.1203
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced summer-sweep-69: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/v071m2r6
# wandb: Find logs at: ./wandb/run-20220222_134101-v071m2r6/logs/debug.log
# wandb:
# wandb: Agent Starting Run: zko7espp with config:
# wandb: 	act_func: relu
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: 4
# wandb: 	hidden_nodes: 32
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_func: cross_entropy
# wandb: 	optimizer: momentum_gd
# wandb: 	reg: 0.0005
# wandb: 	weight_init: random
# wandb: Tracking run with wandb version 0.12.10
# wandb: Syncing run clear-sweep-70
# wandb: ⭐️ View project at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT
# wandb: 🧹 View sweep at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/sweeps/cxmwea0x
# wandb: 🚀 View run at https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/zko7espp
# wandb: Run data is saved locally in /content/wandb/run-20220222_134127-zko7espp
# wandb: Run `wandb offline` to turn off syncing.
#
# signal only works in main thread
#
# wandb: Waiting for W&B process to finish, PID 3104... (success).
# wandb:
# wandb: Run history:
# wandb:     Training_Accuracy ▁▁▁▁▁▁▁▁▁▁
# wandb:         Training_Loss █▇▆▆▅▄▃▃▂▁
# wandb:   Validation_Accuracy ▁▁▁▁▁▁▁▁▁▁
# wandb:       Validation_Loss █▇▆▆▅▄▃▃▂▁
# wandb:                epochs ▁▂▃▃▄▅▆▆▇█
# wandb:         test_accuracy ▁
# wandb:
# wandb: Run summary:
# wandb:     Training_Accuracy 0.1005
# wandb:         Training_Loss 106696.52792
# wandb:   Validation_Accuracy 0.0955
# wandb:       Validation_Loss 106696.52803
# wandb:                epochs 10
# wandb:         test_accuracy 0.1
# wandb:
# wandb: Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb: Synced clear-sweep-70: https://wandb.ai/akashsainics21m003/CS6910_ASSIGNMENT/runs/zko7espp
# wandb: Find logs at: ./wandb/run-20220222_134127-zko7espp/logs/debug.log
# wandb:
